# %%
import requests
from bs4 import BeautifulSoup
import xlrd
import time
import xlsxwriter as xlsxwriter
import csv
import math

import numpy as np
import pandas as pd

# %%
# 파일 불러오기
movie_raw = pd.read_csv("data_ver3.csv")
movie_raw = movie_raw.loc[:, "영화명" : "배우"]
movie = movie_raw

# %%
movie = movie[movie["누적매출액"] != 0]
movie = movie[movie["누적관객수"] != 0]

# %%
movie
# Out:
#                              영화명         개봉일         매출액       누적매출액     관객수  \
# 0                   월드 워 핵전쟁의 서막  2019-03-07       26000       26000      17
# 1                          울프라이징  2016-11-17      300000      300000      60
# 2                제3의앵글 : 형형색색대만전         NaN     1830000     1830000     305
# 3               잃어버린 세계를 찾아 2015  2015-12-03        4000        4000       1
# 4                    과부: 탐스러운 육체  2016-11-19        5000        5000       1
# ...                          ...         ...         ...         ...     ...
# 24878  그대, 고맙소 : 김호중 생애 첫 팬미팅 무비  2020-09-29 -1164993296 -1164993296  102008
# 24879             [통합]회고전, 기획전 등         NaN      985000   501984300     146
# 24880     2006 [통합]영화제/기획전/회고전 등         NaN     1938000   583092200     226
# 24881                  프리즌 이스케이프  2020-05-06  1848297600  1848297600  217056
# 24882               러브 유어셀프 인 서울  2019-01-26 -1085284396 -1085284396  342366
#
# ...

# %%
(movie["누적매출액"] == 0).sum()
# Out:
# 0

# %%
(movie["누적관객수"] == 0).sum()
# Out:
# 0
