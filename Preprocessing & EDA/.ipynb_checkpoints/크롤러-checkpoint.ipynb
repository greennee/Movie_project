# %%
import requests
from bs4 import BeautifulSoup
import time
import xlsxwriter as xlsxwriter
import csv
import math
import re
from datetime import datetime
import numpy as np
import pandas as pd

# %%
movie_raw = pd.read_csv("../Data/train/data_ver4.csv", dtype={'관객수':np.str_, '스크린수':np.str_, '상영횟수':np.str_})
movie_raw.head()
# Out:
#                 영화명         개봉일      매출액    누적매출액  관객수  누적관객수 스크린수 상영횟수  대표국적  \
# 0      월드 워 핵전쟁의 서막  2019-03-07    26000    26000   17     17    5   17  뉴질랜드
# 1             울프라이징  2016-11-17   300000   300000   60     60    1    1    미국
# 2   제3의앵글 : 형형색색대만전         NaN  1830000  1830000  305    305    1    2    대만
# 3  잃어버린 세계를 찾아 2015  2015-12-03     4000     4000    1      1    1    1    미국
# 4       과부: 탐스러운 육체  2016-11-19     5000     5000    1      1    1    1    일본
#
#            배급사        등급      장르          감독                  배우
# 0    주식회사 풍경소리  15세이상관람가      액션    A.K. 스트롬                 NaN
# 1  주식회사 루믹스미디어  15세이상관람가  공포(호러)      BC 퍼트니          빌 오버스트 주니어
# 2          NaN       NaN   애니메이션        BITO                 NaN
# 3     (주)케이알씨지  12세이상관람가    어드벤처  C. 토마스 하우웰  C. 토마스 하우웰,티모시 바톰즈
# 4  (주)영진크리에이티브   청소년관람불가  멜로/로맨스      C.나가후쿠     타치바나 케이코,이치죠 리노

# %%
def main():
    # 파일 불러오기
    movie_raw = pd.read_csv("../Data/train/data_ver4.csv", dtype={'관객수':np.str_, '스크린수':np.str_, '상영횟수':np.str_})
    movie_raw = movie_raw.loc[:, "영화명": "배우"]
    movie = movie_raw

    #  데이터 추출 후 Nan을 빈값으로 바꿔줌
    movie = movie.fillna('')
    movie = movie[9571:10000]

    # 엑셀파일 만들기
    outWorkbook = xlsxwriter.Workbook("Distributor"+ datetime.today().strftime("%Y%m%d%H%M%S")+".xlsx")
    worksheet = outWorkbook.add_worksheet("Distributor")

    #엑셀의 해더를 만든다.
    excel_export_head(worksheet)


    # 엑셀 1행부터 시작하기 위해 선언
    cnt = 1

    # 예외처리 후 프로그램이 돌다 죽을 경우를 대비해서 엑셀파일 생성 여부를 판단하는 구분자.
    excel_yn = False
    try:

        # CSV 파일에서 읽은 데이터 프레임을 행별로 뽑는다.
        for index,row in movie.iterrows():

            distribution = row['배급사']
            grade = row['등급']
            genre= row['장르']
            actor = row['배우']

            # 배급사, 등급, 장르, 배우가 모두 있는경우 크롤링 안함.
            if( len(distribution) > 0 and len(grade) > 0  and len(genre) > 0 and len(actor) > 0):
                movie_dic = {}
                movie_dic['배급사'] = distribution
                movie_dic['등급'] = grade
                movie_dic['장르'] = genre
                movie_dic['배우'] = actor

                print("전처리데이터:", cnt, row['영화명'], " -> ", movie_dic)
                print("--------------------------------------------------")
                # 엑셀파일 생성
                excel_export(worksheet, cnt, row, movie_dic)

            else:

                # 영화리스트에서 해당영화를 찾고 데이터 딕셔너리를 리턴한다.
                movie_dic = movie_search_list(row)

                # 받은 데이터 딕셔너리를 엑셀에 출력한다.
                excel_export(worksheet, cnt, row, movie_dic)
                print("크롤링데이터:",cnt , row['영화명']," -> " , movie_dic)
                print("--------------------------------------------------")

            # 다음행을 가르키기 위해 하나씩 더한다.
            cnt += 1
    except Exception as e:  # 모든 예외의 에러 메시지를 출력할 때는 Exception을 사용
        cnt += 1 # 행번호 증가
        print("예외처리된 영화명 :", cnt, row['영화명'])
        print('예외가 발생했습니다. 예외처리 내용', e)
        print("--------------------------------------------------")
        excel_yn = True # 예외처리후 엑셀을 다시 닫는걸 방지.
        outWorkbook.close() # 엑셀 닫고 생성

    if(excel_yn == False):
        # 엑셀파일을 다 쓴후 닫는다.
        outWorkbook.close()

# %%
def excel_export_head(worksheet):

    worksheet.write(0, 0, "영화명")
    worksheet.write(0, 1, "개봉일")
    worksheet.write(0, 2, "매출액")
    worksheet.write(0, 3, "누적매출액")
    worksheet.write(0, 4, "관객수")
    worksheet.write(0, 5, "누적관객수")
    worksheet.write(0, 6, "스크린수")
    worksheet.write(0, 7, "상영횟수")
    worksheet.write(0, 8, "대표국적")
    worksheet.write(0, 9, "배급사")
    worksheet.write(0, 10, "등급")
    worksheet.write(0, 11, "장르")
    worksheet.write(0, 12, "감독")
    worksheet.write(0, 13, "배우")

# %%
# 엑셀 데이터 쓰기
def excel_export(worksheet,cnt, row,movie_dic):
    worksheet.write(cnt, 0, row['영화명'])
    worksheet.write(cnt, 1, row["개봉일"])
    worksheet.write(cnt, 2, row["매출액"])
    worksheet.write(cnt, 3, row["누적매출액"])
    worksheet.write(cnt, 4, row["관객수"])
    worksheet.write(cnt, 5, row["누적관객수"])
    worksheet.write(cnt, 6, row["스크린수"])
    worksheet.write(cnt, 7, row["상영횟수"])
    worksheet.write(cnt, 8, row["대표국적"])
    worksheet.write(cnt, 9, movie_dic["배급사"])
    worksheet.write(cnt, 10, movie_dic["등급"])
    worksheet.write(cnt, 11, movie_dic["장르"])
    worksheet.write(cnt, 12, row["감독"])
    worksheet.write(cnt, 13, movie_dic["배우"])

# %%
# 네이버 영화리스트 페이지에서 찾고자 하는 영화를 찾는다.
def movie_search_list(row):
    movie_dic = {}
    movie_dic['배급사'] = ""
    movie_dic['등급'] = ""
    movie_dic['장르'] = ""
    movie_dic['배우'] = ""
    movie_name = row['영화명']
    director_name = row["감독"]

    time.sleep(1)

    # 네이버 영화 페이지에서 영화명 검색
    url = 'https://movie.naver.com/movie/search/result.naver?section=movie&query=' + str(movie_name)
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'lxml', from_encoding='utf-8')

    # 검색되는 영화이름 모두 찾기
    # ul 태그의 클래스 search_list_1 찾음
    items = soup.find("ul", {"class": "search_list_1"})

    # 검색되는 영화가 있을 경우 확인
    if (items != None):
        # ul 태그 아래의 li 태그를 모두 찾음
        li_items = items.find_all('li')

        # 결과값을 담을 리스트 생성
        item_list = []
        for li_item in li_items:

            # 결과값을 담을 딕셔너리 생성
            item_dict = {}

            # 영화제목, URL, 감독 값을 태그에서 찾아 딕셔너리
            # 감독명과 타이틀에서 공백을 제거하고 리스트에 넣는다.
            name_tag = li_item.find('dt')
            name = name_tag.text
            if (name.find('(') > -1):
                name = ''.join(name[:name.find('(') - 1].split())  # 모든 공백제거
                item_dict['타이틀'] = name
            else:
                name = ''.join(name.split())  # 모든 공백제거
                item_dict['타이틀'] = name

            movie_url = name_tag.find('a')['href']
            item_dict['주소'] = movie_url
            dd_items = li_item.find_all("dd", {"class": "etc"})

            for dd_item in dd_items:
                dd_tag = dd_item.text

                if (dd_tag.find('감독') != -1):
                    if (dd_tag.find('|') > -1):
                        director_tag = dd_tag[:dd_tag.find('|')]
                        director = str(director_tag).replace('감독 : ', "") # 감독 단어제거
                        director = ''.join(director.split()) # 모든 공백제거
                        item_dict['감독'] = director
                    else:
                        director = dd_tag.replace('감독 : ', "")
                        director = ''.join(director.split())
                        item_dict['감독'] = director

            # 리스트에 딕셔너리를 넣는다
            item_list.append(item_dict)

        #  네이버에서 가져온 영화정보를 CSV 파일에서 가져온 값과 비교를 해서 정말 그 영화인지 찾는다.
        for naver_item in item_list:

            title = naver_item.get('타이틀')
            director = naver_item.get('감독')
            url = str(naver_item.get('주소')).replace('/movie/bi/mi/basic.naver?code=', '')

            director_name =  ''.join(str(director_name).split()) # 전처리 데이터의 감독명 공백제거
            movie_name = ''.join(str(movie_name).split()) # 전처리 데이터 영화이름 공백제거

            if(director != None):
                director_ratio = name_match_ratio(director,director_name) # 크롤링한 감독명과 전처리 데이터의 단어일치율 계산
            else:
                director_ratio = 0 # 크롤링 한 대상에 감독명이 없을 경우 0%

            if(title != None):
                movie_name_ratio = name_match_ratio(title,movie_name) # 크롤링한 감독명과 전처리 데이터의 단어일치율 계산
            else:
                movie_name_ratio = 0 # 크롤링 한 대상에 감독명이 없을 경우 0%


            if (director_ratio >= 60 and movie_name_ratio == 100):

                url = 'https://movie.naver.com/movie/bi/mi/detail.naver?code=' + str(url)
                response = requests.get(url)
                soup = BeautifulSoup(response.content, "lxml", from_encoding="utf-8")

                movie_dic['배급사'] = movie_distribution(soup) # 배급사 찾기함수
                movie_dic['등급'] = movie_grade(soup) # 등급찾기 함수
                movie_dic['장르'] = movie_genre(soup) # 장르찾기 함수
                movie_dic['배우'] = movie_actor(soup) # 배우찾기

                print(' -- 감독명 : ', director, "||", director_name, '-->  일치율: ' ,director_ratio, "%" )
                print(' -- 영화이름 : ', movie_name, "||", title,'-->  일치율: ' ,movie_name_ratio, "%")
                print(' -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-')
            else:

                print(' -- 감독명 : ',director,"||",director_name, '--> 일치율: ' ,director_ratio, "%" )
                print(' -- 영화이름 : ', movie_name, "||", title ,'--> 일치율: ' ,movie_name_ratio, "%" )
                print(' -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-')
                
    return movie_dic

# %%
# 두 단어간 일치 비율을 리턴한다.
def name_match_ratio(word1,word2):

    d1 = list(filter(None,list(word1))) # 공백문자제거
    d1 = list(set(d1).intersection(d1)) # 중복되는 글자 원소 한개만 남김
    d2 = list(filter(None,list(word2))) # 공백문자제거
    d2 = list(set(d2).intersection(d2)) # 중복되는 글자 원소 한개만 남김
    d3 = list(set(d1).intersection(d2)) # 서로 동일한 단어를 리스트화
    if(word1 == word2):
        ratio = 100 #두단어를 비교했는데 정확하게 일치하면 100%
    else:
        # 두단어를 비교했는데 같은 글자의 갯수를 찾고
        ratio = int(len(d3) / len(d1) * 100) # 두 리스트 원소갯수를 비교하여 백분율로 변환
        print(d1,"::",d2,"-->",d3)

    return ratio

# %%
# 배급사정보를 html에서 찾는다.
def movie_distribution(soup):
    distribution = ''

    items = soup.find("dl", {"class": "agency_name"})
    # 배급사 정보가 없을 경우 체크
    if (items != None):

        dt_items = items.find_all('dt')
        dd_items = items.find_all('dd')
        for idx, i in enumerate(dt_items):
            # 배급사 정보 체크
            if (i.text == '배급'):
                distribution = str(dd_items[idx].text).replace('\n', '').replace('\t','').replace('\r','')
    return distribution

# %%
# 등급을 html에서 찾는다.
def movie_grade(soup):
    grade = ''

    items = soup.find("dl", {"class": "info_spec"})
    # 등급 정보가 없을 경우 체크
    if (items != None):

        dt_items = items.find_all('dt')
        dd_items = items.find_all('dd')
        for idx, i in enumerate(dt_items):
            # 등급 정보 체크
            if (i.text == '등급'):
                grad_line = str(dd_items[idx].text).replace('\n', '').replace('\r', '').replace('\t', '')
                if(grad_line.find('[해외]')> -1):
                    grade = grad_line[:grad_line.find('[해외]')].replace('[국내] ','')
                else:
                    grade = grad_line
    return grade

# %%
def movie_genre(soup):
    genre = ''

    items = soup.find("dl", {"class": "info_spec"})
    # 장르 정보가 없을 경우 체크
    if (items != None):

        dt_items = items.find_all('dt')
        dd_items = items.find_all('dd')
        for idx, i in enumerate(dt_items):
            # 장르 정보 체크
            if (str(i.text).find('개요') > -1):
                dd_spans = dd_items[idx].find_all('span')
                genre = str(dd_spans[0].text).replace('\n', '').replace('\r', '').replace('\t', '').split(',')[0]
    return genre

# %%
def movie_actor(soup):
    actor = ''
    actor_namelist = []
    items = soup.find("ul", {"class": "lst_people"})
    # 배우 정보가 없을 경우 체크
    if (items != None):
        # 모든 배우이름을 찾는다.
        a_items = items.find_all('a', {"class": "k_name"})
        # 배우이름을 담을 리스트를 만든다.

        # 찾은 모든 배우를 찾아 리스트에 담는다.
        for idx, i in enumerate(a_items):
            # 배우 정보 체크
            actor_name = str(i.text)
            actor_namelist.append(actor_name)
            # 4번째부터는 안넣음.
            if(idx == 2):
                break
    if actor_namelist != None:
        actor = ",".join(actor_namelist)

    return actor

# %%
if __name__ == '__main__':
    main()
# Out:
#  -- 감독명 :  알렉산더소쿠로프 || 알렉산더소쿠로프 -->  일치율:  100 %
#  -- 영화이름 :  일식의날 || 일식의날 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 1 일식의 날  ->  {'배급사': '', '등급': '15세 관람가 ', '장르': '드라마', '배우': '알렉세이 아나니시노프,에스켄더 우마로프,블라디미르 자만스키'}
# --------------------------------------------------
# ['등', '화', '도'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
# [':', '리', '아', '자', '빠', '우', '황', '소'] :: ['자', '리', '황', '소'] --> ['자', '황', '리', '소']
#  -- 감독명 :  등화도 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  황소자리 || 황소자리:우리아빠 --> 일치율:  50 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 2 황소자리  ->  {'배급사': '', '등급': '', '장르': '', '배우': ''}
# --------------------------------------------------
# ['레', '르', '리', '이', '도', '아', '헬', '나', '마', '스', '키', '에', ',', '시', '가'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
#  -- 감독명 :  마리나이스키에도가르시아,헬레나이스키에도가르시아 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  태양 || 태양 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['유', '에', '리', '이'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
#  -- 감독명 :  이리에유 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  태양 || 태양 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['리', '고', '베', '플', '네', '덱', '프'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> ['프']
#  -- 감독명 :  베네덱플리고프 || 알렉산더소쿠로프 --> 일치율:  14 %
#  -- 영화이름 :  태양 || 태양 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['어', '이', '벨', '우', '노', '바', '베'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
#  -- 감독명 :  베벨노이바우어 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  태양 || 태양 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['미', '이', '리', '히', '노', '코', '로', '즈'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> ['로']
# ['양', '태', '노', '래', '의'] :: ['양', '태'] --> ['양', '태']
#  -- 감독명 :  코이즈미노리히로 || 알렉산더소쿠로프 --> 일치율:  12 %
#  -- 영화이름 :  태양 || 태양의노래 --> 일치율:  40 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['혁', '진'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
# ['양', '군', '태', '주', '의'] :: ['양', '태'] --> ['양', '태']
#  -- 감독명 :  진혁 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  태양 || 주군의태양 --> 일치율:  40 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['탈', '리', '스', '키', '만', '비'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
# ['아', '양', '태', '래'] :: ['양', '태'] --> ['양', '태']
#  -- 감독명 :  비탈리만스키 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  태양 || 태양아래 --> 일치율:  50 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['후', '아', '안', '쿠', '톤'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> ['쿠']
# ['양', '물', '태', '의', '눈'] :: ['양', '태'] --> ['양', '태']
#  -- 감독명 :  안톤후쿠아 || 알렉산더소쿠로프 --> 일치율:  20 %
#  -- 영화이름 :  태양 || 태양의눈물 --> 일치율:  40 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['버', '그', '티', '필', '스', '븐'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
# ['국', '양', '태', '제', '의'] :: ['양', '태'] --> ['양', '태']
#  -- 감독명 :  스티븐스필버그 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  태양 || 태양의제국 --> 일치율:  40 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['은', '재', '정'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
# ['양', '풍', '태'] :: ['양', '태'] --> ['양', '태']
#  -- 감독명 :  정재은 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  태양 || 태풍태양 --> 일치율:  66 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 3 태양  ->  {'배급사': '', '등급': '', '장르': '', '배우': ''}
# --------------------------------------------------
#  -- 감독명 :  알렉산더소쿠로프 || 알렉산더소쿠로프 -->  일치율:  100 %
#  -- 영화이름 :  생의엘레지-로스트로포비치와비쉬넵스카야 || 생의엘레지-로스트로포비치와비쉬넵스카야 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 4 생의 엘레지 - 로스트로포비치와 비쉬넵스카야  ->  {'배급사': '', '등급': '', '장르': '다큐멘터리', '배우': '갈리나 비슈네브스카야,알렉산더 소쿠로프,크지슈토프 펜데렉키'}
# --------------------------------------------------
#  -- 감독명 :  알렉산더소쿠로프 || 알렉산더소쿠로프 -->  일치율:  100 %
#  -- 영화이름 :  모스크바엘레지 || 모스크바엘레지 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 5 모스크바 엘레지  ->  {'배급사': '', '등급': '[국내] 15세 관람가', '장르': '다큐멘터리', '배우': '알렉산더 소쿠로프'}
# --------------------------------------------------
# ['취', '로', '몰'] :: ['흐', '로', '몰'] --> ['로', '몰']
#  -- 감독명 :  알렉산더소쿠로프 || 알렉산더소쿠로프 --> 일치율:  100 %
#  -- 영화이름 :  몰로흐 || 몰로취 --> 일치율:  66 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 6 몰로흐  ->  {'배급사': '', '등급': '', '장르': '', '배우': ''}
# --------------------------------------------------
#  -- 감독명 :  알렉산더소쿠로프 || 알렉산더소쿠로프 -->  일치율:  100 %
#  -- 영화이름 :  긴여정의엘레지 || 긴여정의엘레지 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 7 긴 여정의 엘레지  ->  {'배급사': '', '등급': '[국내] 15세 관람가', '장르': '다큐멘터리', '배우': ''}
# --------------------------------------------------
#  -- 감독명 :  알렉산더소쿠로프 || 알렉산더소쿠로프 -->  일치율:  100 %
#  -- 영화이름 :  오리엔탈엘레지 || 오리엔탈엘레지 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 8 오리엔탈 엘레지  ->  {'배급사': '', '등급': '[국내] 15세 관람가', '장르': '드라마', '배우': ''}
# --------------------------------------------------
#  -- 감독명 :  알렉산더소쿠로프 || 알렉산더소쿠로프 -->  일치율:  100 %
#  -- 영화이름 :  인간의고독한목소리 || 인간의고독한목소리 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 9 인간의 고독한 목소리  ->  {'배급사': '', '등급': '15세 관람가 ', '장르': '드라마', '배우': '안드레이 그라도브,타티아나 고랴체바,니콜라이 코헤가로브'}
# --------------------------------------------------
#  -- 감독명 :  알렉산더소쿠로프 || 알렉산더소쿠로프 -->  일치율:  100 %
#  -- 영화이름 :  영혼의목소리 || 영혼의목소리 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 10 영혼의 목소리  ->  {'배급사': '', '등급': '', '장르': '다큐멘터리', '배우': ''}
# --------------------------------------------------
# ['카', '럽', '파', '트', '스', '로'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> ['로']
#  -- 감독명 :  카스파로스트럽 || 알렉산더소쿠로프 --> 일치율:  16 %
#  -- 영화이름 :  어머니와아들 || 어머니와아들 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
#  -- 감독명 :  알렉산더소쿠로프 || 알렉산더소쿠로프 -->  일치율:  100 %
#  -- 영화이름 :  어머니와아들 || 어머니와아들 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['섭', '유', '이'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
#  -- 감독명 :  이유섭 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  어머니와아들 || 어머니와아들 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['안', '재', '민'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
# ['어', '니', '아', '나', '머', '들', ',', '의'] :: ['어', '아', '들', '머', '와', '니'] --> ['어', '아', '들', '머', '니']
#  -- 감독명 :  안재민 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  어머니와아들 || 나의아들,나의어머니 --> 일치율:  62 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['이', '루', '라', '울', '즈'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
# ['두', '어', '아', '들', '머', '니', '의'] :: ['어', '아', '들', '머', '와', '니'] --> ['어', '아', '들', '머', '니']
#  -- 감독명 :  라울루이즈 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  어머니와아들 || 두어머니의아들 --> 일치율:  71 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['상', '이', '인'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
# ['어', '아', '신', '들', '머', '니', ',', '의', '당'] :: ['어', '아', '들', '머', '와', '니'] --> ['어', '아', '들', '머', '니']
#  -- 감독명 :  이상인 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  어머니와아들 || 어머니,당신의아들 --> 일치율:  55 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['지', '테', '리', '조'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
# ['어', '니', '아', '들', '머', '느'] :: ['어', '아', '들', '머', '와', '니'] --> ['어', '아', '들', '머', '니']
#  -- 감독명 :  테리조지 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  어머니와아들 || 어느어머니아들 --> 일치율:  83 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 11 어머니와 아들  ->  {'배급사': '', '등급': '', '장르': '독일', '배우': ''}
# --------------------------------------------------
# ['마', '스', '톡', '토', '만'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
#  -- 감독명 :  토마스스톡만 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  아버지와아들 || 아버지와아들 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['델', '달', '키', '타'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
#  -- 감독명 :  타달델키 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  아버지와아들 || 아버지와아들 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['우', '양', '초', '리'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
# [':', '버', '지', '몽', '희', '아', '생', '인', '와', '들'] :: ['지', '버', '아', '와', '들'] --> ['지', '버', '아', '와', '들']
#  -- 감독명 :  양리초우 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  아버지와아들 || 희몽인생:아버지와아들 --> 일치율:  50 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['리', '치', '앤', '로', '류', '드'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> ['로']
#  -- 감독명 :  앤드류로리치 || 알렉산더소쿠로프 --> 일치율:  16 %
#  -- 영화이름 :  아버지와아들 || 아버지와아들 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['몬', '처', '피', '슈', '시'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
#  -- 감독명 :  시몬슈피처 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  아버지와아들 || 아버지와아들 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['빙', '왕'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
#  -- 감독명 :  왕빙 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  아버지와아들 || 아버지와아들 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['양', '오', '샤'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
#  -- 감독명 :  샤오양 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  아버지와아들 || 아버지와아들 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['베', '이', '칼', '세'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
#  -- 감독명 :  칼베세이 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  아버지와아들 || 아버지와아들 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['안', '허', '유'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
#  -- 감독명 :  허유안 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  아버지와아들 || 아버지와아들 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['담', '명', '가'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
#  -- 감독명 :  담가명 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  아버지와아들 || 아버지와아들 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 12 아버지와 아들  ->  {'배급사': '', '등급': '', '장르': '', '배우': ''}
# --------------------------------------------------
#  -- 감독명 :  알렉산더소쿠로프 || 알렉산더소쿠로프 -->  일치율:  100 %
#  -- 영화이름 :  알렉산드라 || 알렉산드라 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['드', '주', '라'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
#  -- 감독명 :  라드주드 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  알렉산드라 || 알렉산드라 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['클', '너', '샤', '린', '랭', 'J', '.', '프'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> ['프']
# ['산', '렉', '콜', '스', '알', '라', '와', '니', '드'] :: ['산', '렉', '알', '라', '드'] --> ['산', '렉', '알', '라', '드']
#  -- 감독명 :  프랭클린J.샤프너 || 알렉산더소쿠로프 --> 일치율:  12 %
#  -- 영화이름 :  알렉산드라 || 니콜라스와알렉산드라 --> 일치율:  55 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['모', '리', '센', '나', '스', '베', '유', '테', '프'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> ['프']
# ['미', '산', '아', '렉', '알', '라', '와', '드'] :: ['산', '렉', '알', '라', '드'] --> ['산', '렉', '알', '라', '드']
#  -- 감독명 :  모나프리스베테유센 || 알렉산더소쿠로프 --> 일치율:  11 %
#  -- 영화이름 :  알렉산드라 || 미아와알렉산드라 --> 일치율:  62 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['어', '롤', '히', '드', '프'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> ['프']
# ['산', '략', '렉', '계', '알', '라', '드', '의'] :: ['산', '렉', '알', '라', '드'] --> ['산', '렉', '알', '라', '드']
#  -- 감독명 :  롤프드히어 || 알렉산더소쿠로프 --> 일치율:  20 %
#  -- 영화이름 :  알렉산드라 || 알렉산드라의계략 --> 일치율:  62 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['레', '르', '콧', '아', '스', '니', '드'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
# ['모', '오', '산', '이', '얼', '튼', '피', '렉', '트', '알', '언', '셜', '라', '드', '브'] :: ['산', '렉', '알', '라', '드'] --> ['산', '렉', '알', '라', '드']
#  -- 감독명 :  스콧레니아르드 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  알렉산드라 || 언오피셜트라이얼오브알렉산드라모튼 --> 일치율:  33 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['미', '오', '리', '디', '트', '스', '키', '패'] :: ['산', '렉', '더', '알', '소', '로', '쿠', '프'] --> []
# ['미', '산', '이', '렉', '더', '스', '알', '라', '츠', '툰', '드', '페'] :: ['산', '렉', '알', '라', '드'] --> ['산', '렉', '알', '라', '드']
#  -- 감독명 :  디미트리스패트리키오스 || 알렉산더소쿠로프 --> 일치율:  0 %
#  -- 영화이름 :  알렉산드라 || 알렉산드라미츠더스페이스툰스 --> 일치율:  41 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 13 알렉산드라  ->  {'배급사': '스폰지', '등급': '[국내] 전체 관람가', '장르': '드라마', '배우': '갈리나 비슈네브스카야,바실리 셰프소브,알렉세이 네이미쉐브'}
# --------------------------------------------------
#  -- 감독명 :  알렉산더소쿠로프 || 알렉산더소쿠로프 -->  일치율:  100 %
#  -- 영화이름 :  러시아방주 || 러시아방주 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 14 러시아 방주  ->  {'배급사': '', '등급': '', '장르': '드라마', '배우': ''}
# --------------------------------------------------
# 전처리데이터: 15 프랑코포니아  ->  {'배급사': '(주)영화사 안다미로', '등급': '12세이상관람가', '장르': '드라마', '배우': '루이-도 드 렝퀘셍,빈센트 네메스'}
# --------------------------------------------------
# 전처리데이터: 16 파우스트  ->  {'배급사': '㈜영화사 백두대간', '등급': '청소년관람불가', '장르': '드라마', '배우': '요하네스 자일러,게오르그 프리드리히,한나 쉬굴라,앙뜨완느 모노 주니어,이솔다 디차우크,안톤 아다신스키'}
# --------------------------------------------------
# 전처리데이터: 17 엑스텐션  ->  {'배급사': '(유)영화사 화수분,인트로미디어(주)', '등급': '18세관람가', '장르': '공포(호러)', '배우': '마이웬 르 베스코,필립 나혼,세실 드 프랑스'}
# --------------------------------------------------
# 전처리데이터: 18 나인스 라이프  ->  {'배급사': '(주)라이크콘텐츠', '등급': '15세이상관람가', '장르': '미스터리', '배우': '제이미 도넌,사라 가돈,아론 폴'}
# --------------------------------------------------
# 전처리데이터: 19 혼스  ->  {'배급사': '(주)팝엔터테인먼트', '등급': '청소년관람불가', '장르': '판타지', '배우': '다니엘 래드클리프,주노 템플'}
# --------------------------------------------------
# 전처리데이터: 20 크롤  ->  {'배급사': '롯데컬처웍스(주)롯데엔터테인먼트', '등급': '15세이상관람가', '장르': '액션', '배우': '카야 스코델라리오,배리 페퍼'}
# --------------------------------------------------
# 전처리데이터: 21 피라냐  ->  {'배급사': '에스케이텔레콤(주)', '등급': '청소년관람불가', '장르': '액션', '배우': '엘리자베스 슈,제시카 스자르,제리 오코넬,아담 스콧,빙 라메스'}
# --------------------------------------------------
# 전처리데이터: 22 배틀독  ->  {'배급사': '스크린조이', '등급': '청소년관람불가', '장르': '공포(호러)', '배우': '크레이그 셰퍼,데니스 헤이스버트,케이트 버논'}
# --------------------------------------------------
#  -- 감독명 :  알렉산더코르다 || 알렉산더코르다 -->  일치율:  100 %
#  -- 영화이름 :  해밀턴부인 || 해밀턴부인 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 23 해밀턴 부인  ->  {'배급사': '', '등급': '12세 관람가 ', '장르': '모험', '배우': '비비안 리,로렌스 올리비에,앨런 모우브레이'}
# --------------------------------------------------
# 전처리데이터: 24 배틀트립 투 그리스  ->  {'배급사': '(주)영화사오원', '등급': '12세이상관람가', '장르': '코미디', '배우': '발레리 보네통,대니 분'}
# --------------------------------------------------
# 전처리데이터: 25 노엘의 선물  ->  {'배급사': '(주)나이너스엔터테인먼트', '등급': '전체관람가', '장르': '코미디', '배우': '타하르 라힘,빅토르 카발'}
# --------------------------------------------------
# 전처리데이터: 26 디센던트  ->  {'배급사': '이십세기폭스코리아(주)', '등급': '15세이상관람가', '장르': '코미디', '배우': '조지 클루니,주디 그리어'}
# --------------------------------------------------
# 전처리데이터: 27 다운사이징  ->  {'배급사': '롯데쇼핑㈜롯데엔터테인먼트', '등급': '15세이상관람가', '장르': '드라마', '배우': '맷 데이먼,크리스틴 위그,크리스토프 왈츠,제이슨 서디키스'}
# --------------------------------------------------
# 전처리데이터: 28 밤쉘  ->  {'배급사': '(주)영화사 그램', '등급': '15세이상관람가', '장르': '다큐멘터리', '배우': '헤디 라머'}
# --------------------------------------------------
# ['리', '엔', '케', '라', '푸', '테'] :: ['산', '헤', '렉', '트', '알', '라', '메', '로', '바', '드'] --> ['라']
#  -- 감독명 :  엔리케라푸엔테 || 알렉산드라헤트메로바 --> 일치율:  16 %
#  -- 영화이름 :  수영장 || 수영장 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['고', '유', '희'] :: ['산', '헤', '렉', '트', '알', '라', '메', '로', '바', '드'] --> []
#  -- 감독명 :  고유희 || 알렉산드라헤트메로바 --> 일치율:  0 %
#  -- 영화이름 :  수영장 || 수영장 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['모', '리', '타', '키', '사'] :: ['산', '헤', '렉', '트', '알', '라', '메', '로', '바', '드'] --> []
#  -- 감독명 :  모리타사키 || 알렉산드라헤트메로바 --> 일치율:  0 %
#  -- 영화이름 :  수영장 || 수영장 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['르', '린', '트', '본', '키', '로', '바', '니', '드'] :: ['산', '헤', '렉', '트', '알', '라', '메', '로', '바', '드'] --> ['바', '드', '로', '트']
#  -- 감독명 :  니키린드로트본바르 || 알렉산드라헤트메로바 --> 일치율:  44 %
#  -- 영화이름 :  수영장 || 수영장 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['듀', '키', '토', '멕'] :: ['산', '헤', '렉', '트', '알', '라', '메', '로', '바', '드'] --> []
#  -- 감독명 :  토멕듀키 || 알렉산드라헤트메로바 --> 일치율:  0 %
#  -- 영화이름 :  수영장 || 수영장 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['를', '킨', '카', '텔', '스', '로', '라'] :: ['산', '헤', '렉', '트', '알', '라', '메', '로', '바', '드'] --> ['로', '라']
#  -- 감독명 :  카를로스킨텔라 || 알렉산드라헤트메로바 --> 일치율:  28 %
#  -- 영화이름 :  수영장 || 수영장 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
#  -- 감독명 :  알렉산드라헤트메로바 || 알렉산드라헤트메로바 -->  일치율:  100 %
#  -- 영화이름 :  수영장 || 수영장 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['모', '미', '오', '리', '카'] :: ['산', '헤', '렉', '트', '알', '라', '메', '로', '바', '드'] --> []
#  -- 감독명 :  오오모리미카 || 알렉산드라헤트메로바 --> 일치율:  0 %
#  -- 영화이름 :  수영장 || 수영장 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['레', '이', '자', '크', '드'] :: ['산', '헤', '렉', '트', '알', '라', '메', '로', '바', '드'] --> ['드']
#  -- 감독명 :  자크드레이 || 알렉산드라헤트메로바 --> 일치율:  20 %
#  -- 영화이름 :  수영장 || 수영장 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['슈', '를', '르', '질'] :: ['산', '헤', '렉', '트', '알', '라', '메', '로', '바', '드'] --> []
# ['간', '수', '영', '자', '장', '로', '들', '으', '남'] :: ['장', '영', '수'] --> ['장', '수', '영']
#  -- 감독명 :  질를르슈 || 알렉산드라헤트메로바 --> 일치율:  0 %
#  -- 영화이름 :  수영장 || 수영장으로간남자들 --> 일치율:  33 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 29 수영장  ->  {'배급사': '', '등급': '', '장르': '애니메이션', '배우': ''}
# --------------------------------------------------
# 전처리데이터: 30 내 아내의 여자  ->  {'배급사': '(주)우성엔터테인먼트', '등급': '청소년관람불가', '장르': '미스터리', '배우': '크리스타나 로켄'}
# --------------------------------------------------
# 전처리데이터: 31 2047: 지구 최후의 날  ->  {'배급사': '(주)소나무픽쳐스', '등급': '15세이상관람가', '장르': '액션', '배우': '대니 글로버,대릴 한나,스티븐 볼드윈,마이클 매드슨,룻거 하우어'}
# --------------------------------------------------
# 전처리데이터: 32 은밀한 가족  ->  {'배급사': '(주)엔케이컨텐츠', '등급': '청소년관람불가', '장르': '드라마', '배우': '테미스 파누,엘레니 로시누'}
# --------------------------------------------------
# ['오', '르', '렉', '상', '필', '립', '알', '드'] :: ['산', '르', 'O', '렉', '필', '립', '알', '드', '.'] --> ['르', '렉', '필', '립', '알', '드']
#  -- 감독명 :  알렉상드르오필립 || 알렉산드르O.필립 -->  일치율:  75 %
#  -- 영화이름 :  점쟁이문어파울의일생 || 점쟁이문어파울의일생 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 33 점쟁이 문어 파울의 일생  ->  {'배급사': '', '등급': '[국내] 전체 관람가', '장르': '다큐멘터리', '배우': '스테판 포르볼,가비 바르케'}
# --------------------------------------------------
# ['산', '르', '도', '렉', '첸', '알', '코', '드', '브'] :: ['산', '르', '도', '렉', '알', '젠', '코', '드', '브'] --> ['드', '산', '르', '렉', '알', '코', '도', '브']
#  -- 감독명 :  알렉산드르도브첸코 || 알렉산드르도브젠코 -->  일치율:  88 %
#  -- 영화이름 :  아에로그라드 || 아에로그라드 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 34 아에로그라드  ->  {'배급사': '', '등급': '[국내] 15세 관람가', '장르': '드라마', '배우': '스테판 샤건가이다,세르게이 스톨랴로프,예브게니아 멜니코바'}
# --------------------------------------------------
# 크롤링데이터: 35 병기고  ->  {'배급사': '', '등급': '', '장르': '', '배우': ''}
# --------------------------------------------------
# ['산', '르', '도', '렉', '첸', '알', '코', '드', '브'] :: ['산', '르', '도', '렉', '알', '젠', '코', '드', '브'] --> ['드', '산', '르', '렉', '알', '코', '도', '브']
#  -- 감독명 :  알렉산드르도브첸코 || 알렉산드르도브젠코 -->  일치율:  88 %
#  -- 영화이름 :  즈베니고라 || 즈베니고라 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 36 즈베니고라  ->  {'배급사': '', '등급': '', '장르': '90분 ', '배우': ''}
# --------------------------------------------------
# ['버', '즈', '자', '네', '거'] :: ['산', '르', '도', '렉', '알', '젠', '코', '드', '브'] --> []
#  -- 감독명 :  자네즈버거 || 알렉산드르도브젠코 --> 일치율:  0 %
#  -- 영화이름 :  이반 || 이반 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['다', '나', '알', '바', '비', '도', '료'] :: ['산', '르', '도', '렉', '알', '젠', '코', '드', '브'] --> ['도', '알']
#  -- 감독명 :  알료나다비도바 || 알렉산드르도브젠코 --> 일치율:  28 %
#  -- 영화이름 :  이반 || 이반 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['산', '르', '도', '렉', '첸', '알', '코', '드', '브'] :: ['산', '르', '도', '렉', '알', '젠', '코', '드', '브'] --> ['드', '산', '르', '렉', '알', '코', '도', '브']
#  -- 감독명 :  알렉산드르도브첸코 || 알렉산드르도브젠코 -->  일치율:  88 %
#  -- 영화이름 :  이반 || 이반 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['레', '르', '이', '안', '타', '스', '키', '코', '드', '프'] :: ['산', '르', '도', '렉', '알', '젠', '코', '드', '브'] --> ['드', '르', '코']
# ['절', '어', '이', '린', '반', '시', '의'] :: ['반', '이'] --> ['반', '이']
#  -- 감독명 :  안드레이타르코프스키 || 알렉산드르도브젠코 --> 일치율:  30 %
#  -- 영화이름 :  이반 || 이반의어린시절 --> 일치율:  28 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['르', '이', '게', '타', '젠', '인', '세', '슈', '에'] :: ['산', '르', '도', '렉', '알', '젠', '코', '드', '브'] --> ['르', '젠']
# ['1', '이', '군', '반', '부', '폭'] :: ['반', '이'] --> ['반', '이']
#  -- 감독명 :  세르게이에이젠슈타인 || 알렉산드르도브젠코 --> 일치율:  22 %
#  -- 영화이름 :  이반 || 폭군이반1부 --> 일치율:  33 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['석', '이', '현'] :: ['산', '르', '도', '렉', '알', '젠', '코', '드', '브'] --> []
# ['병', '반', '용', '이'] :: ['반', '이'] --> ['반', '이']
#  -- 감독명 :  이현석 || 알렉산드르도브젠코 --> 일치율:  0 %
#  -- 영화이름 :  이반 || 용병이반 --> 일치율:  50 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['르', '이', '게', '타', '젠', '인', '세', '슈', '에'] :: ['산', '르', '도', '렉', '알', '젠', '코', '드', '브'] --> ['르', '젠']
# ['이', '2', '군', '반', '부', '폭'] :: ['반', '이'] --> ['반', '이']
#  -- 감독명 :  세르게이에이젠슈타인 || 알렉산드르도브젠코 --> 일치율:  22 %
#  -- 영화이름 :  이반 || 폭군이반2부 --> 일치율:  33 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['영', '이'] :: ['산', '르', '도', '렉', '알', '젠', '코', '드', '브'] --> []
# ['두', '웃', '이', '째', '아', '야', '열', '번', '반', '검', '기', '-'] :: ['반', '이'] --> ['반', '이']
#  -- 감독명 :  이영 || 알렉산드르도브젠코 --> 일치율:  0 %
#  -- 영화이름 :  이반 || 아웃-이반검열두번째이야기 --> 일치율:  16 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['오', '미', '슬', '로', '셸'] :: ['산', '르', '도', '렉', '알', '젠', '코', '드', '브'] --> []
# ['레', '이', '차', '치', '반', '공', '와', '비', '주'] :: ['반', '이'] --> ['반', '이']
#  -- 감독명 :  미셸오슬로 || 알렉산드르도브젠코 --> 일치율:  0 %
#  -- 영화이름 :  이반 || 이반차레비치와공주 --> 일치율:  22 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['영', '이'] :: ['산', '르', '도', '렉', '알', '젠', '코', '드', '브'] --> []
# ['검', '반', '이', '열'] :: ['반', '이'] --> ['반', '이']
#  -- 감독명 :  이영 || 알렉산드르도브젠코 --> 일치율:  0 %
#  -- 영화이름 :  이반 || 이반검열 --> 일치율:  50 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 37 이반  ->  {'배급사': '', '등급': '', '장르': '102분 ', '배우': ''}
# --------------------------------------------------
# ['줄', '리', '내', '아', '코', '쉬', '쿠', '렌'] :: ['산', '르', '도', '렉', '알', '젠', '코', '드', '브'] --> ['코']
#  -- 감독명 :  줄리아쿠쉬내렌코 || 알렉산드르도브젠코 --> 일치율:  12 %
#  -- 영화이름 :  대지 || 대지 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['지', '오', '르', '니', '루', '세', '비'] :: ['산', '르', '도', '렉', '알', '젠', '코', '드', '브'] --> ['르']
#  -- 감독명 :  세르지오루비니 || 알렉산드르도브젠코 --> 일치율:  14 %
#  -- 영화이름 :  대지 || 대지 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['오', '뎀', '리', '메', '훌'] :: ['산', '르', '도', '렉', '알', '젠', '코', '드', '브'] --> []
#  -- 감독명 :  훌리오메뎀 || 알렉산드르도브젠코 --> 일치율:  0 %
#  -- 영화이름 :  대지 || 대지 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['클', '린', '랭', '니', '드', '시', '프'] :: ['산', '르', '도', '렉', '알', '젠', '코', '드', '브'] --> ['드']
#  -- 감독명 :  시드니프랭클린 || 알렉산드르도브젠코 --> 일치율:  14 %
#  -- 영화이름 :  대지 || 대지 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['산', '르', '도', '렉', '첸', '알', '코', '드', '브'] :: ['산', '르', '도', '렉', '알', '젠', '코', '드', '브'] --> ['드', '산', '르', '렉', '알', '코', '도', '브']
#  -- 감독명 :  알렉산드르도브첸코 || 알렉산드르도브젠코 -->  일치율:  88 %
#  -- 영화이름 :  대지 || 대지 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['모', '르', '리', '아', '길', '예', '가'] :: ['산', '르', '도', '렉', '알', '젠', '코', '드', '브'] --> ['르']
# ['지', '망', '대', '욕', '의'] :: ['지', '대'] --> ['지', '대']
#  -- 감독명 :  길예르모아리아가 || 알렉산드르도브젠코 --> 일치율:  14 %
#  -- 영화이름 :  대지 || 욕망의대지 --> 일치율:  40 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['티', '루', '콘', '스', '치', '노', '비'] :: ['산', '르', '도', '렉', '알', '젠', '코', '드', '브'] --> []
# ['지', '흔', '리', '는', '대', '들'] :: ['지', '대'] --> ['지', '대']
#  -- 감독명 :  루치노비스콘티 || 알렉산드르도브젠코 --> 일치율:  0 %
#  -- 영화이름 :  대지 || 흔들리는대지 --> 일치율:  33 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['디', '스', '리'] :: ['산', '르', '도', '렉', '알', '젠', '코', '드', '브'] --> []
# ['지', '치', '대', '욕', '의'] :: ['지', '대'] --> ['지', '대']
#  -- 감독명 :  디리스 || 알렉산드르도브젠코 --> 일치율:  0 %
#  -- 영화이름 :  대지 || 치욕의대지 --> 일치율:  40 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['지', '미', '오', '르', '카', '잔', '게', '세', '니', '-'] :: ['산', '르', '도', '렉', '알', '젠', '코', '드', '브'] --> ['르']
# ['지', '둥', '대', '기', '의'] :: ['지', '대'] --> ['지', '대']
#  -- 감독명 :  세르지오미니카-게잔 || 알렉산드르도브젠코 --> 일치율:  10 %
#  -- 영화이름 :  대지 || 대지의기둥 --> 일치율:  40 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['지', '른', '마', '존', '목', '생', '대', '의'] :: ['지', '대'] --> ['지', '대']
#  -- 감독명 :  None || 알렉산드르도브젠코 --> 일치율:  0 %
#  -- 영화이름 :  대지 || 목마른생존의대지 --> 일치율:  25 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 38 대지  ->  {'배급사': '', '등급': '', '장르': '러시아(구 소련)', '배우': ''}
# --------------------------------------------------
# 전처리데이터: 39 테라노바  ->  {'배급사': '(주)나우콘텐츠', '등급': '청소년관람불가', '장르': '액션', '배우': '콘스탄틴 라브로넨코,마라 바샤로프'}
# --------------------------------------------------
# 크롤링데이터: 40 빛나라, 내 별이여  ->  {'배급사': '', '등급': '', '장르': '', '배우': ''}
# --------------------------------------------------
# ['미', '산', '렉', '타', '더', '알'] :: ['미', '산', '르', '렉', '타', '알', '드'] --> ['미', '산', '렉', '타', '알']
#  -- 감독명 :  알렉산더미타 || 알렉산드르미타 -->  일치율:  83 %
#  -- 영화이름 :  샤갈-말레비치 || 샤갈-말레비치 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 41 샤갈-말레비치  ->  {'배급사': '', '등급': '', '장르': '드라마', '배우': ''}
# --------------------------------------------------
# 전처리데이터: 42 정글  ->  {'배급사': '주식회사 루믹스미디어', '등급': '12세이상관람가', '장르': '어드벤처', '배우': '세르게이 스베틀라코프,베라 브레즈네바'}
# --------------------------------------------------
# 전처리데이터: 43 레닌그라드: 900일간의 전투  ->  {'배급사': '(주)소나무픽쳐스', '등급': '15세이상관람가', '장르': '전쟁', '배우': '미라 소르비노,아민 뮬러 스탈'}
# --------------------------------------------------
# 전처리데이터: 44 영웅 - 샐러멘더의 비밀  ->  {'배급사': '익스트림 필름', '등급': '15세이상관람가', '장르': '액션', '배우': '김보성,룻거 하우어'}
# --------------------------------------------------
# ['튜', '매', '르', '리', '텔', '에', '포', '렉', '상', '파', '델', '알', '라', '드', ',', '테'] :: ['튜', '매', '르', '리', '텔', '에', '포', '렉', '상', '파', '델', '알', '라', '드', ',', '테'] --> ['튜', '매', '드', '르', '리', '텔', '포', '렉', '상', '파', '델', '알', '라', '에', ',', '테']
#  -- 감독명 :  알렉상드르드라파텔리에르,매튜델라포테 || 알렉상드르드라파텔리에르,매튜델라포르테 -->  일치율:  100 %
#  -- 영화이름 :  그이름은... || 그이름은... -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['스', '든', '고', '세'] :: ['튜', '매', '르', '리', '텔', '에', '포', '렉', '상', '파', '델', '알', '라', '드', ',', '테'] --> []
# ['레', '그', '를', '르', '이', '직', '상', '트', '는', '스', '장', '사', '부', '름'] :: ['그', '이', '은', '.', '름'] --> ['그', '이', '름']
#  -- 감독명 :  세스고든 || 알렉상드르드라파텔리에르,매튜델라포르테 --> 일치율:  0 %
#  -- 영화이름 :  그이름은... || 스트레스를부르는그이름직장상사 --> 일치율:  21 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['이', '나', '타', '키', '츠', '유', '가'] :: ['튜', '매', '르', '리', '텔', '에', '포', '렉', '상', '파', '델', '알', '라', '드', ',', '테'] --> []
# ['그', '모', '을', '이', '리', '직', '아', '다', '꽃', '른', '본', '날', '우', '는', '의', '름'] :: ['그', '이', '은', '.', '름'] --> ['그', '이', '름']
#  -- 감독명 :  나가이타츠유키 || 알렉상드르드라파텔리에르,매튜델라포르테 --> 일치율:  0 %
#  -- 영화이름 :  그이름은... || 그날본꽃의이름을우리는아직모른다 --> 일치율:  18 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['숀', '더', '스', '앤'] :: ['튜', '매', '르', '리', '텔', '에', '포', '렉', '상', '파', '델', '알', '라', '드', ',', '테'] --> []
# ['레', '그', '를', '르', '이', '직', '2', '상', '트', '는', '스', '장', '사', '부', '름'] :: ['그', '이', '은', '.', '름'] --> ['그', '이', '름']
#  -- 감독명 :  숀앤더스 || 알렉상드르드라파텔리에르,매튜델라포르테 --> 일치율:  0 %
#  -- 영화이름 :  그이름은... || 스트레스를부르는그이름직장상사2 --> 일치율:  20 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['카', '이', '야', '라', '시', '즈'] :: ['튜', '매', '르', '리', '텔', '에', '포', '렉', '상', '파', '델', '알', '라', '드', ',', '테'] --> ['라']
# ['새', '이', '는', '없', '름'] :: ['그', '이', '은', '.', '름'] --> ['이', '름']
#  -- 감독명 :  시라이시카즈야 || 알렉상드르드라파텔리에르,매튜델라포르테 --> 일치율:  16 %
#  -- 영화이름 :  그이름은... || 이름없는새 --> 일치율:  40 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['그', '이', '…', '은', '의', '름'] :: ['그', '이', '은', '.', '름'] --> ['그', '은', '이', '름']
#  -- 감독명 :  None || 알렉상드르드라파텔리에르,매튜델라포르테 --> 일치율:  0 %
#  -- 영화이름 :  그이름은... || 그의이름은… --> 일치율:  66 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['김', '석', '환'] :: ['튜', '매', '르', '리', '텔', '에', '포', '렉', '상', '파', '델', '알', '라', '드', ',', '테'] --> []
# ['버', '그', '레', '이', '트', '은', '의', '름'] :: ['그', '이', '은', '.', '름'] --> ['그', '은', '이', '름']
#  -- 감독명 :  김석환 || 알렉상드르드라파텔리에르,매튜델라포르테 --> 일치율:  0 %
#  -- 영화이름 :  그이름은... || 그의이름은트레버 --> 일치율:  50 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['범', '철', '권'] :: ['튜', '매', '르', '리', '텔', '에', '포', '렉', '상', '파', '델', '알', '라', '드', ',', '테'] --> []
# ['버', '그', '어', '이', '린', '들', '잃', '름'] :: ['그', '이', '은', '.', '름'] --> ['그', '이', '름']
#  -- 감독명 :  권철범 || 알렉상드르드라파텔리에르,매튜델라포르테 --> 일치율:  0 %
#  -- 영화이름 :  그이름은... || 그들이잃어버린이름 --> 일치율:  37 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['노', '필'] :: ['튜', '매', '르', '리', '텔', '에', '포', '렉', '상', '파', '델', '알', '라', '드', ',', '테'] --> []
# ['그', '을', '이', '리', '잊', '으', '름'] :: ['그', '이', '은', '.', '름'] --> ['그', '이', '름']
#  -- 감독명 :  노필 || 알렉상드르드라파텔리에르,매튜델라포르테 --> 일치율:  0 %
#  -- 영화이름 :  그이름은... || 그이름을잊으리 --> 일치율:  42 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['엘', '디', '트', '로', '비', '젝', '프'] :: ['튜', '매', '르', '리', '텔', '에', '포', '렉', '상', '파', '델', '알', '라', '드', ',', '테'] --> []
# ['그', '이', '시', '도', '은', '의', '름'] :: ['그', '이', '은', '.', '름'] --> ['그', '은', '이', '름']
#  -- 감독명 :  프로젝트비디엘 || 알렉상드르드라파텔리에르,매튜델라포르테 --> 일치율:  0 %
#  -- 영화이름 :  그이름은... || 그의이름은도시 --> 일치율:  57 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 45 그 이름은...  ->  {'배급사': '', '등급': '', '장르': '코미디', '배우': '패트릭 브루엘,발레리에 벵귀귀,샤를스 베르링'}
# --------------------------------------------------
# 전처리데이터: 46 레더페이스  ->  {'배급사': '(주)드림팩트엔터테인먼트', '등급': '청소년관람불가', '장르': '공포(호러)', '배우': '스티븐 도프,릴리 테일러'}
# --------------------------------------------------
# 전처리데이터: 47 십계: 구원의 길  ->  {'배급사': '(주)키다리이엔티', '등급': '전체관람가', '장르': '드라마', '배우': '길례르미 윈터,세르지오 마로네,카밀라 로드리게즈,지젤 이티에'}
# --------------------------------------------------
# ['리', '스', '판', '제', '테', '브'] :: ['오', '르', '렉', '상', '트', '스', '알', '럭', '드'] --> ['스']
#  -- 감독명 :  스테판브리제 || 알렉상드르오스트럭 --> 일치율:  16 %
#  -- 영화이름 :  여자의일생 || 여자의일생 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['호', '태', '박'] :: ['오', '르', '렉', '상', '트', '스', '알', '럭', '드'] --> []
#  -- 감독명 :  박호태 || 알렉상드르오스트럭 --> 일치율:  0 %
#  -- 영화이름 :  여자의일생 || 여자의일생 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['옥', '상', '신'] :: ['오', '르', '렉', '상', '트', '스', '알', '럭', '드'] --> ['상']
#  -- 감독명 :  신상옥 || 알렉상드르오스트럭 --> 일치율:  33 %
#  -- 영화이름 :  여자의일생 || 여자의일생 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['경', '신', '균'] :: ['오', '르', '렉', '상', '트', '스', '알', '럭', '드'] --> []
#  -- 감독명 :  신경균 || 알렉상드르오스트럭 --> 일치율:  0 %
#  -- 영화이름 :  여자의일생 || 여자의일생 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['르', '아', '렉', '상', '트', '스', '뤽', '알', '드'] :: ['오', '르', '렉', '상', '트', '스', '알', '럭', '드'] --> ['르', '렉', '상', '트', '스', '알', '드']
#  -- 감독명 :  알렉상드르아스트뤽 || 알렉상드르오스트럭 -->  일치율:  77 %
#  -- 영화이름 :  여자의일생 || 여자의일생 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['마', '잰', '렛', '슨'] :: ['오', '르', '렉', '상', '트', '스', '알', '럭', '드'] --> []
#  -- 감독명 :  마렛잰슨 || 알렉상드르오스트럭 --> 일치율:  0 %
#  -- 영화이름 :  여자의일생 || 여자의일생 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['한', '김', '일'] :: ['오', '르', '렉', '상', '트', '스', '알', '럭', '드'] --> []
# ['그', '여', '자', '일', '생', '의'] :: ['여', '자', '생', '일', '의'] --> ['여', '자', '일', '생', '의']
#  -- 감독명 :  김한일 || 알렉상드르오스트럭 --> 일치율:  0 %
#  -- 영화이름 :  여자의일생 || 그여자의일생 --> 일치율:  83 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 48 여자의 일생  ->  {'배급사': '', '등급': '', '장르': '드라마', '배우': '마리아 쉘,크리스티앙 마르캉,루이 아르베지에르'}
# --------------------------------------------------
# 전처리데이터: 49 러브 인 비즈니스클래스  ->  {'배급사': '(주)마인스 엔터테인먼트', '등급': '청소년관람불가', '장르': '멜로/로맨스', '배우': '루디빈 사니에,니콜라스 베도스,조나단 코헨'}
# --------------------------------------------------
# 전처리데이터: 50 뮨: 달의 요정  ->  {'배급사': '(주)스마일이엔티,씨네그루(주)다우기술', '등급': '전체관람가', '장르': '애니메이션', '배우': '조슈아 J. 발라드,오마 사이'}
# --------------------------------------------------
# 전처리데이터: 51 엄마의 유산  ->  {'배급사': '(주)에스와이코마드', '등급': '12세이상관람가', '장르': '가족', '배우': '리야 넬스카야,유브게니 쥬마노프,옥산나 보이첸코'}
# --------------------------------------------------
# 전처리데이터: 52 하얼빈대전투: 일본군최후의날  ->  {'배급사': '미디어소프트', '등급': '15세이상관람가', '장르': '전쟁', '배우': '로만 폴란스키'}
# --------------------------------------------------
# ['레', '이', '렉', '샤', '파', '알', '바', '세'] :: ['레', '이', '렉', '샤', '파', '알', '세', '프'] --> ['레', '이', '렉', '샤', '파', '알', '세']
#  -- 감독명 :  알렉세이샤파레바 || 알렉세이샤파레프 -->  일치율:  87 %
#  -- 영화이름 :  싸움의법칙 || 싸움의법칙 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 53 싸움의 법칙  ->  {'배급사': '', '등급': '[국내] 15세 관람가', '장르': '액션', '배우': '보리스 아브라모프,에브게니 갈리치'}
# --------------------------------------------------
# 전처리데이터: 54 T-34  ->  {'배급사': '㈜코리아스크린', '등급': '12세이상관람가', '장르': '전쟁', '배우': '알렉산더 페트로브,이리나 스타르셴바움'}
# --------------------------------------------------
#  -- 감독명 :  알렉세이암브로시에프 || 알렉세이암브로시에프 -->  일치율:  100 %
#  -- 영화이름 :  길잃은사람들 || 길잃은사람들 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['롤', '캐', '룹', '트', '스', '인', '라'] :: ['이', '렉', '암', '알', '로', '세', '에', '시', '브', '프'] --> []
#  -- 감독명 :  캐롤라인스트룹 || 알렉세이암브로시에프 --> 일치율:  0 %
#  -- 영화이름 :  길잃은사람들 || 길잃은사람들 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['한', '김', '일'] :: ['이', '렉', '암', '알', '로', '세', '에', '시', '브', '프'] --> []
#  -- 감독명 :  김한일 || 알렉세이암브로시에프 --> 일치율:  0 %
#  -- 영화이름 :  길잃은사람들 || 길잃은사람들 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 55 길 잃은 사람들  ->  {'배급사': '', '등급': '[국내] 15세 관람가', '장르': '러시아 연방', '배우': '다닐 오시포프,갈리나 티코노바'}
# --------------------------------------------------
# 전처리데이터: 56 스나이퍼  ->  {'배급사': '(주)소나무픽쳐스', '등급': '15세이상관람가', '장르': '드라마', '배우': '비아체슬라프 크리쿠노프'}
# --------------------------------------------------
# 전처리데이터: 57 시베리아 횡단열차: 대탈주  ->  {'배급사': '(주)소나무픽쳐스', '등급': '청소년관람불가', '장르': '드라마', '배우': '블라디미르 마쉬코프'}
# --------------------------------------------------
#  -- 감독명 :  알렉세이유치텔 || 알렉세이유치텔 -->  일치율:  100 %
#  -- 영화이름 :  마틸다:황제의연인 || 마틸다:황제의연인 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 58 마틸다: 황제의 연인  ->  {'배급사': '(주)영화사 오원', '등급': '[국내] 15세 관람가', '장르': '드라마', '배우': '라르스 아이딩어,미할리나 올샨스카,루이제 볼프람'}
# --------------------------------------------------
# 전처리데이터: 59 눈의 여왕 3: 눈과 불의 마법대결  ->  {'배급사': '(주)이수C&E', '등급': '전체관람가', '장르': '애니메이션', '배우': '박지윤,엄상현,남도형,박상훈,이재범'}
# --------------------------------------------------
#  -- 감독명 :  알렉세이트시칠린 || 알렉세이트시칠린 -->  일치율:  100 %
#  -- 영화이름 :  눈의여왕2:트롤의마법거울 || 눈의여왕2:트롤의마법거울 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 60 눈의 여왕 2: 트롤의 마법거울  ->  {'배급사': '씨네그루(주)키다리이엔티', '등급': '[국내] 전체 관람가', '장르': '애니메이션', '배우': '벨라 손,샬토 코플리,숀 빈'}
# --------------------------------------------------
# 크롤링데이터: 61 혁명의 천사들  ->  {'배급사': '', '등급': '', '장르': '', '배우': ''}
# --------------------------------------------------
#  -- 감독명 :  알렉세이페옥티스토프 || 알렉세이페옥티스토프 -->  일치율:  100 %
#  -- 영화이름 :  스파이:외인부대잠입작전 || 스파이:외인부대잠입작전 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 62 스파이: 외인부대 잠입작전  ->  {'배급사': '', '등급': '[국내] 15세 관람가', '장르': '액션', '배우': ''}
# --------------------------------------------------
#  -- 감독명 :  알렉세이페옥티스토프 || 알렉세이페옥티스토프 -->  일치율:  100 %
#  -- 영화이름 :  탱크:독일전차군단을격파하라 || 탱크:독일전차군단을격파하라 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 63 탱크: 독일전차군단을 격파하라  ->  {'배급사': '', '등급': '[국내] 15세 관람가', '장르': '전쟁', '배우': '보리스 클리우예브'}
# --------------------------------------------------
# 전처리데이터: 64 아마도 내일은  ->  {'배급사': 'C 무비', '등급': '12세이상관람가', '장르': '드라마', '배우': '알릭스 베네치크,플로렝 아르누'}
# --------------------------------------------------
# ['르', '이', '트', '스', '치', '반', '코', '조'] :: ['렉', 'S', '스', '알', '라', '.', '브'] --> ['스']
#  -- 감독명 :  이스트반조르코치 || 알렉스S.라브 --> 일치율:  12 %
#  -- 영화이름 :  어쌔신크리드2 || 어쌔신크리드2 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 65 어쌔신 크리드 2  ->  {'배급사': '', '등급': '', '장르': '', '배우': ''}
# --------------------------------------------------
# 전처리데이터: 66 엑스 마키나  ->  {'배급사': '유니버설픽쳐스인터내셔널 코리아(유)', '등급': '청소년관람불가', '장르': 'SF', '배우': '도널 글리슨,알리시아 비칸데르,오스카 아이삭'}
# --------------------------------------------------
# 전처리데이터: 67 아메리칸 오지  ->  {'배급사': '㈜코리아스크린', '등급': '청소년관람불가', '장르': '코미디', '배우': '제이슨 서디키스,레슬리 빕,타일러 라빈'}
# --------------------------------------------------
# 전처리데이터: 68 마녀사냥꾼  ->  {'배급사': '(주)도키엔터테인먼트', '등급': '청소년관람불가', '장르': '판타지', '배우': '휴고 실바,마리오 카사스'}
# --------------------------------------------------
# 전처리데이터: 69 광대를 위한 슬픈 발라드  ->  {'배급사': '오드', '등급': '청소년관람불가', '장르': '공포(호러)', '배우': '카를로스 아레세스,안토니오 드 라 토레,캐롤라이나 뱅'}
# --------------------------------------------------
#  -- 감독명 :  알렉스드라이글레시아 || 알렉스드라이글레시아 -->  일치율:  100 %
#  -- 영화이름 :  더바 || 더바 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['이', '리', '슬', '언', '라', '워'] :: ['레', '글', '이', '아', '렉', '스', '알', '라', '드', '시'] --> ['이', '라']
# ['이', '징', '더', '바', '라'] :: ['더', '바'] --> ['더', '바']
#  -- 감독명 :  라이언워슬리 || 알렉스드라이글레시아 --> 일치율:  33 %
#  -- 영화이름 :  더바 || 라이징더바 --> 일치율:  40 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['슨', '헤', '이', '리', '들', '제'] :: ['레', '글', '이', '아', '렉', '스', '알', '라', '드', '시'] --> ['이']
# ['더', '앳', '바'] :: ['더', '바'] --> ['더', '바']
#  -- 감독명 :  제이슨헤들리 || 알렉스드라이글레시아 --> 일치율:  16 %
#  -- 영화이름 :  더바 || 앳더바 --> 일치율:  66 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['리', '퍼', '스', '크', '토', '로', '메'] :: ['레', '글', '이', '아', '렉', '스', '알', '라', '드', '시'] --> ['스']
# ['어', '툴', '이', '더', '스', '바', '세', '비'] :: ['더', '바'] --> ['더', '바']
#  -- 감독명 :  크리스토퍼로메로 || 알렉스드라이글레시아 --> 일치율:  14 %
#  -- 영화이름 :  더바 || 더바스툴세이비어 --> 일치율:  25 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['리', '찰', '린', '채', '플'] :: ['레', '글', '이', '아', '렉', '스', '알', '라', '드', '시'] --> []
# ['어', '이', '온', '스', '더', '룸', '바', '로', '플', '페'] :: ['더', '바'] --> ['더', '바']
#  -- 감독명 :  찰리채플린 || 알렉스드라이글레시아 --> 일치율:  0 %
#  -- 영화이름 :  더바 || 페이스온더바룸플로어 --> 일치율:  20 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['위', '트', '스', '조', '니'] :: ['레', '글', '이', '아', '렉', '스', '알', '라', '드', '시'] --> ['스']
# [':', '오', '운', '셧', '다', '트', '콜', '스', '더', 'Y', '라', 'C', '바', 'N', '브'] :: ['더', '바'] --> ['더', '바']
#  -- 감독명 :  조니스위트 || 알렉스드라이글레시아 --> 일치율:  20 %
#  -- 영화이름 :  더바 || 라스트콜스:더셧다운오브NYC바 --> 일치율:  13 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['미', '릴', '리', '트', '사'] :: ['레', '글', '이', '아', '렉', '스', '알', '라', '드', '시'] --> []
# ['온', '더', '스', '크', '로', '바'] :: ['더', '바'] --> ['더', '바']
#  -- 감독명 :  사미트릴리 || 알렉스드라이글레시아 --> 일치율:  0 %
#  -- 영화이름 :  더바 || 온더크로스바 --> 일치율:  33 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['파', '마', '릿', '스', '니', '테', '거'] :: ['레', '글', '이', '아', '렉', '스', '알', '라', '드', '시'] --> ['스']
# ['너', '리', '더', '스', '임', '서', '라', '바'] :: ['더', '바'] --> ['더', '바']
#  -- 감독명 :  스테파니마거릿 || 알렉스드라이글레시아 --> 일치율:  14 %
#  -- 영화이름 :  더바 || 더너서리라임스바 --> 일치율:  25 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['마', '크', '인', '메'] :: ['레', '글', '이', '아', '렉', '스', '알', '라', '드', '시'] --> []
# [':', '더', '치', '바', '비', '무'] :: ['더', '바'] --> ['더', '바']
#  -- 감독명 :  마크메인 || 알렉스드라이글레시아 --> 일치율:  0 %
#  -- 영화이름 :  더바 || 비치바:더무비 --> 일치율:  33 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['이', '잭', '언', '라', '브'] :: ['레', '글', '이', '아', '렉', '스', '알', '라', '드', '시'] --> ['이', '라']
# [':', '오', '이', '리', '아', '다', '터', '더', '크', '스', '라', '토', '베', '바', '애', '시', '브', '프'] :: ['더', '바'] --> ['더', '바']
#  -- 감독명 :  잭브라이언 || 알렉스드라이글레시아 --> 일치율:  40 %
#  -- 영화이름 :  더바 || 라이프애프터다크:더스토리오브시베리아바 --> 일치율:  11 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 70 더 바  ->  {'배급사': '(주)영화사 그램', '등급': '[국내] 15세 관람가', '장르': '스릴러', '배우': '블랑카 수아레즈,마리오 카사스,세컨 드 라 로사'}
# --------------------------------------------------
# 전처리데이터: 71 아메리칸 레슬러: 더 위저드  ->  {'배급사': '주식회사 락희상회', '등급': '12세이상관람가', '장르': '드라마', '배우': '조지 코스투로스,존 보이트,윌리엄 피츠너'}
# --------------------------------------------------
# 전처리데이터: 72 체크 메이트 캅  ->  {'배급사': '(주)케이알씨지', '등급': '15세이상관람가', '장르': '액션', '배우': '팻 조,알렉스 매소네트'}
# --------------------------------------------------
# 전처리데이터: 73 엔드오브왓치: NYPD  ->  {'배급사': '주식회사 루믹스미디어', '등급': '청소년관람불가', '장르': '액션', '배우': '마이클 라이트'}
# --------------------------------------------------
# 전처리데이터: 74 악령의 집  ->  {'배급사': '(주)나우콘텐츠', '등급': '청소년관람불가', '장르': '스릴러', '배우': '피터 폰다,테렌스 하워드'}
# --------------------------------------------------
# 전처리데이터: 75 앨티튜드  ->  {'배급사': '(주)제이에이와이이엔터테인먼트', '등급': '15세이상관람가', '장르': '액션', '배우': '데니스 리차드,돌프 룬드그렌,조나단 립니키'}
# --------------------------------------------------
# 크롤링데이터: 76 자, 서쪽으로  ->  {'배급사': '', '등급': '', '장르': '', '배우': ''}
# --------------------------------------------------
# 전처리데이터: 77 더 트러스트  ->  {'배급사': '(주)케이알씨지', '등급': '15세이상관람가', '장르': '범죄', '배우': '니콜라스 케이지,일라이저 우드'}
# --------------------------------------------------
# 전처리데이터: 78 포가튼 : 잊혀진 소녀  ->  {'배급사': '㈜영화사 백두대간', '등급': '15세이상관람가', '장르': '드라마', '배우': '미나 탄더,카타리나 탈바흐,로라 드 보어'}
# --------------------------------------------------
# ['미', '렉', '스', '알', '앤', '류', 'J', '드', ',', '.'] :: ['미', '스', '렉', '알'] --> ['알', '미', '스', '렉']
#  -- 감독명 :  알렉스스미스,앤드류J.스미스 || 알렉스스미스 --> 일치율:  40 %
#  -- 영화이름 :  로스트인마운틴 || 로스트인마운틴 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 79 로스트 인 마운틴  ->  {'배급사': '', '등급': '', '장르': '', '배우': ''}
# --------------------------------------------------
# ['렉', '타', '스', '더', '알', '만', '슈'] :: ['렉', '타', '스', '더', '알', '만'] --> ['렉', '타', '스', '더', '알', '만']
#  -- 감독명 :  알렉스슈타더만 || 알렉스스타더만 -->  일치율:  85 %
#  -- 영화이름 :  100%울프:푸들이될순없어 || 100%울프:푸들이될순없어 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 80 100% 울프: 푸들이 될 순 없어  ->  {'배급사': '(주)팝엔터테인먼트', '등급': '[국내] 전체 관람가', '장르': '애니메이션', '배우': ''}
# --------------------------------------------------
# 전처리데이터: 81 마야  ->  {'배급사': '(주)박수엔터테인먼트', '등급': '전체관람가', '장르': '애니메이션', '배우': '김서영,홍소영'}
# --------------------------------------------------
#  -- 감독명 :  알렉스앤완터 || 알렉스앤완터 -->  일치율:  100 %
#  -- 영화이름 :  유윌네버비얼론 || 유윌네버비얼론 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 82 유 윌 네버 비 얼론  ->  {'배급사': '', '등급': '', '장르': '드라마', '배우': '안토니아 제거스,세르지오 헤르난데즈,에드가르도 브루나'}
# --------------------------------------------------
# 전처리데이터: 83 스페이스 치킨: 마법 부적의 비밀  ->  {'배급사': '(주)박수엔터테인먼트', '등급': '전체관람가', '장르': '애니메이션', '배우': '류승곤,이인석,이명희,안현서,오마 카파로,크리스티앙 드 라 푸엔테,제시카 세디엘'}
# --------------------------------------------------
# 전처리데이터: 84 미이라  ->  {'배급사': '유니버설픽쳐스인터내셔널 코리아(유)', '등급': '15세이상관람가', '장르': '액션', '배우': '톰 크루즈,소피아 부텔라,애나벨 월리스,러셀 크로우,하비에르 보텟,제이크 존슨,코트니 B. 반스,딜란 스미스'}
# --------------------------------------------------
#  -- 감독명 :  알렉스켄드릭 || 알렉스켄드릭 -->  일치율:  100 %
#  -- 영화이름 :  용기와구원 || 용기와구원 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 85 용기와 구원  ->  {'배급사': '', '등급': '12세 관람가 ', '장르': '드라마', '배우': '알렉스 켄드릭,켄 비벨,케빈 다운즈'}
# --------------------------------------------------
#  -- 감독명 :  알렉스켄드릭 || 알렉스켄드릭 -->  일치율:  100 %
#  -- 영화이름 :  기도의힘 || 기도의힘 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 86 기도의 힘  ->  {'배급사': '(주)더쿱', '등급': '12세 관람가 ', '장르': '드라마', '배우': '프리실라 C. 샤이어,카렌 애버크롬비,T.C. 스탤링스'}
# --------------------------------------------------
# 전처리데이터: 87 믿음의 승부  ->  {'배급사': '크로스픽쳐스(주)', '등급': '전체관람가', '장르': '드라마', '배우': '제임스 블랙웰,베일리 케이브'}
# --------------------------------------------------
# 전처리데이터: 88 하펫 꿈나라 모험  ->  {'배급사': '페어팍스인터내셔날(주)', '등급': '전체관람가', '장르': '애니메이션', '배우': '조경이,김나율'}
# --------------------------------------------------
# 전처리데이터: 89 원 밀리언 킥  ->  {'배급사': '(주)박수엔터테인먼트', '등급': '15세이상관람가', '장르': '액션', '배우': '마틴 바덴'}
# --------------------------------------------------
# ['벤', '자', '거'] :: ['렉', '야', '스', '알', '로', '프'] --> []
# [':', '뱀', '어', '티', '이', '습', '다', '파', '크', '격', '시', '의'] :: ['다', '크', '티', '시'] --> ['다', '크', '티', '시']
#  -- 감독명 :  벤자거 || 알렉스프로야스 --> 일치율:  0 %
#  -- 영화이름 :  다크시티 || 다크시티:뱀파이어의습격 --> 일치율:  33 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
#  -- 감독명 :  알렉스프로야스 || 알렉스프로야스 -->  일치율:  100 %
#  -- 영화이름 :  다크시티 || 다크시티 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['J', '스', '키', '바', '로', '저', '.'] :: ['렉', '야', '스', '알', '로', '프'] --> ['스', '로']
#  -- 감독명 :  로저J.바스키 || 알렉스프로야스 --> 일치율:  28 %
#  -- 영화이름 :  다크시티 || 다크시티 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['리', '윌', '디', '터', '엄'] :: ['렉', '야', '스', '알', '로', '프'] --> []
#  -- 감독명 :  윌리엄디터리 || 알렉스프로야스 --> 일치율:  0 %
#  -- 영화이름 :  다크시티 || 다크시티 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['티', '아', '트', 'T', '더', '스'] :: ['렉', '야', '스', '알', '로', '프'] --> ['스']
# ['니', '티', '다', '트', '스', '더', '크', '비', '시'] :: ['다', '크', '티', '시'] --> ['다', '크', '티', '시']
#  -- 감독명 :  TT더아티스트 || 알렉스프로야스 --> 일치율:  16 %
#  -- 영화이름 :  다크시티 || 다크시티비니스더비트 --> 일치율:  44 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['리', '피', '신', '토', '니', '시'] :: ['렉', '야', '스', '알', '로', '프'] --> []
# ['스', '키', '친', '헬'] :: ['다', '크', '티', '시'] --> []
#  -- 감독명 :  토니신시리피니 || 알렉스프로야스 --> 일치율:  0 %
#  -- 영화이름 :  다크시티 || 헬스키친 --> 일치율:  0 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['프', '버', '리', '트', '랭', '게', '밀', '크', '로', '드', ',', '즈', '러'] :: ['렉', '야', '스', '알', '로', '프'] --> ['로', '프']
# [':', '어', '티', '다', '히', '크', '씬', '로', '활', '부', '시', '의'] :: ['다', '크', '티', '시'] --> ['다', '크', '티', '시']
#  -- 감독명 :  프랭크밀러,로버트로드리게즈 || 알렉스프로야스 --> 일치율:  15 %
#  -- 영화이름 :  다크시티 || 씬시티:다크히어로의부활 --> 일치율:  33 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['니', '체', '이', '언'] :: ['렉', '야', '스', '알', '로', '프'] --> []
# ['을', '도', '는', '키', '별', '삼', '시'] :: ['다', '크', '티', '시'] --> ['시']
#  -- 감독명 :  이언체니 || 알렉스프로야스 --> 일치율:  0 %
#  -- 영화이름 :  다크시티 || 별을삼키는도시 --> 일치율:  14 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 90 다크시티  ->  {'배급사': '', '등급': '', '장르': '', '배우': ''}
# --------------------------------------------------
# 전처리데이터: 91 갓 오브 이집트  ->  {'배급사': '(주)시네마서비스,(주)나이너스엔터테인먼트', '등급': '12세이상관람가', '장르': '어드벤처', '배우': '제라드 버틀러,니콜라이 코스터 왈도,코트니 이튼,브렌튼 스웨이츠,애비 리'}
# --------------------------------------------------
# ['하', '오', '르', '데', '렉', '스', '알', '베', '울', '니', '실', '네', ',', '테'] :: ['하', '오', '데', '르', '렉', '스', '알', ',', '베', '니', '실', '네', '울', '테'] --> ['하', '오', '데', '르', '렉', '스', '알', '베', '울', '니', '실', '네', ',', '테']
#  -- 감독명 :  데니실베르테오네,알렉스하울 || 알렉스하울,데니실베르테오네 -->  일치율:  100 %
#  -- 영화이름 :  베토벤의가발 || 베토벤의가발 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 92 베토벤의 가발  ->  {'배급사': '', '등급': '', '장르': '애니메이션', '배우': ''}
# --------------------------------------------------
# ['카', '콜', '스', '라', '니', '시', '맥'] :: ['이', '달', '렉', '게', '스', '호', '알', '라', '언', '비', ',', '브'] --> ['스', '라']
# ['디', '지', '로', '프'] :: ['지', '디', '더', '로', '프'] --> ['지', '디', '로', '프']
#  -- 감독명 :  니콜라스맥카시 || 알렉스호게이,브라이언비달 --> 일치율:  28 %
#  -- 영화이름 :  더프로디지 || 프로디지 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
#  -- 감독명 :  알렉스호게이,브라이언비달 || 알렉스호게이,브라이언비달 -->  일치율:  100 %
#  -- 영화이름 :  더프로디지 || 더프로디지 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['이', '자', '온', '스', '크', '라'] :: ['이', '달', '렉', '게', '스', '호', '알', '라', '언', '비', ',', '브'] --> ['스', '이', '라']
#  -- 감독명 :  자크라이온스 || 알렉스호게이,브라이언비달 --> 일치율:  50 %
#  -- 영화이름 :  더프로디지 || 더프로디지 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['덤', '애', '리'] :: ['이', '달', '렉', '게', '스', '호', '알', '라', '언', '비', ',', '브'] --> []
#  -- 감독명 :  애덤리 || 알렉스호게이,브라이언비달 --> 일치율:  0 %
#  -- 영화이름 :  더프로디지 || 더프로디지 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 93 더 프로디지  ->  {'배급사': '', '등급': '[국내] 15세 관람가', '장르': '드라마', '배우': '사반나 라일스,리처드 닐,에밀리오 팔람'}
# --------------------------------------------------
# 전처리데이터: 94 스무살의 침대  ->  {'배급사': '주식회사 마운틴픽쳐스', '등급': '청소년관람불가', '장르': '드라마', '배우': '데보라 프랑수아,페르난도 티엘브'}
# --------------------------------------------------
# ['보', '황', '정'] :: ['레', '미', '몬', '고', '렉', '뎅', '트', '스', '알', ',', '보', '시'] --> ['보']
# ['고', '렛', '츠', '!'] :: ['고', '렛', '츠'] --> ['고', '렛', '츠']
#  -- 감독명 :  황정보 || 알렉시스보몬트,레미고뎅 --> 일치율:  33 %
#  -- 영화이름 :  렛츠고 || 렛츠고! --> 일치율:  75 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['모', '리', '마', '키', '토', '코', '와'] :: ['레', '미', '몬', '고', '렉', '뎅', '트', '스', '알', ',', '보', '시'] --> []
# ['두', '모', '리', '♪', '고', '☆', '파', '경', '장', '렛', '츠', '판', '라', '동', '극', '의', '프'] :: ['고', '렛', '츠'] --> ['고', '렛', '츠']
#  -- 감독명 :  모리와키마코토 || 알렉시스보몬트,레미고뎅 --> 일치율:  0 %
#  -- 영화이름 :  렛츠고 || 극장판프리파라모두의동경♪렛츠고☆프리파리 --> 일치율:  17 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['김', '형', '오'] :: ['레', '미', '몬', '고', '렉', '뎅', '트', '스', '알', ',', '보', '시'] --> []
# ['간', '험', '2', '고', '렛', '츠', '대', '시', '탐'] :: ['고', '렛', '츠'] --> ['고', '렛', '츠']
#  -- 감독명 :  김형오 || 알렉시스보몬트,레미고뎅 --> 일치율:  0 %
#  -- 영화이름 :  렛츠고 || 렛츠고시간탐험대2 --> 일치율:  33 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['오', '덴', '크', '커', '밥'] :: ['레', '미', '몬', '고', '렉', '뎅', '트', '스', '알', ',', '보', '시'] --> []
# ['슨', '리', '고', '투', '렛', '츠', '프'] :: ['고', '렛', '츠'] --> ['고', '렛', '츠']
#  -- 감독명 :  밥오덴커크 || 알렉시스보몬트,레미고뎅 --> 일치율:  0 %
#  -- 영화이름 :  렛츠고 || 렛츠고투프리슨 --> 일치율:  42 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['김', '형', '오'] :: ['레', '미', '몬', '고', '렉', '뎅', '트', '스', '알', ',', '보', '시'] --> []
# ['간', '1', '험', '고', '렛', '츠', '대', '시', '탐'] :: ['고', '렛', '츠'] --> ['고', '렛', '츠']
#  -- 감독명 :  김형오 || 알렉시스보몬트,레미고뎅 --> 일치율:  0 %
#  -- 영화이름 :  렛츠고 || 렛츠고시간탐험대1 --> 일치율:  33 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['오', '카', '다', '사', '네', '무'] :: ['레', '미', '몬', '고', '렉', '뎅', '트', '스', '알', ',', '보', '시'] --> []
# ['전', '오', '이', '고', '왕', '올', '더', '렛', '츠', '라', '면', '·', '즈', '가'] :: ['고', '렛', '츠'] --> ['고', '렛', '츠']
#  -- 감독명 :  카네다오사무 || 알렉시스보몬트,레미고뎅 --> 일치율:  0 %
#  -- 영화이름 :  렛츠고 || 오즈·전왕·올라이더렛츠고가면라이더 --> 일치율:  21 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['레', '미', '몬', '고', '렉', '트', '스', '알', ',', '보', '시', '딘'] :: ['레', '미', '몬', '고', '렉', '뎅', '트', '스', '알', ',', '보', '시'] --> ['레', '미', '몬', '고', '렉', '트', '스', '알', ',', '시', '보']
#  -- 감독명 :  알렉시스보몬트,레미고딘 || 알렉시스보몬트,레미고뎅 -->  일치율:  91 %
#  -- 영화이름 :  렛츠고 || 렛츠고 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['고', '온', '렛', '츠', '컴'] :: ['고', '렛', '츠'] --> ['고', '렛', '츠']
#  -- 감독명 :  None || 알렉시스보몬트,레미고뎅 --> 일치율:  0 %
#  -- 영화이름 :  렛츠고 || 컴온렛츠고 --> 일치율:  60 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['하', '미', '엘', '어', '회', '벤', '페'] :: ['레', '미', '몬', '고', '렉', '뎅', '트', '스', '알', ',', '보', '시'] --> ['미']
# ['고', '렛', '츠', '!'] :: ['고', '렛', '츠'] --> ['고', '렛', '츠']
#  -- 감독명 :  미하엘페어회벤 || 알렉시스보몬트,레미고뎅 --> 일치율:  14 %
#  -- 영화이름 :  렛츠고 || 렛츠고! --> 일치율:  75 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['모', '야', '타', '마', '토', '츠', '쿠'] :: ['레', '미', '몬', '고', '렉', '뎅', '트', '스', '알', ',', '보', '시'] --> []
# ['홈', '고', '렛', '츠'] :: ['고', '렛', '츠'] --> ['고', '렛', '츠']
#  -- 감독명 :  마츠모토타쿠야 || 알렉시스보몬트,레미고뎅 --> 일치율:  0 %
#  -- 영화이름 :  렛츠고 || 렛츠고홈 --> 일치율:  75 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ...
# 크롤링데이터: 376 엠넷 개똥벌레편  ->  {'배급사': '', '등급': '', '장르': '', '배우': ''}
# --------------------------------------------------
# 크롤링데이터: 377 엠넷 무당벌레편  ->  {'배급사': '', '등급': '', '장르': '', '배우': ''}
# --------------------------------------------------
#  -- 감독명 :  야네스헨드릭즈 || 야네스헨드릭즈 -->  일치율:  100 %
#  -- 영화이름 :  유나이티드항공-해양의오케스트라 || 유나이티드항공-해양의오케스트라 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 378 유나이티드 항공 - 해양의 오케스트라  ->  {'배급사': '', '등급': '', '장르': '애니메이션', '배우': ''}
# --------------------------------------------------
# 크롤링데이터: 379 프리스키즈 어드벤처랜드  ->  {'배급사': '', '등급': '', '장르': '', '배우': ''}
# --------------------------------------------------
#  -- 감독명 :  야네스헨드릭즈 || 야네스헨드릭즈 -->  일치율:  100 %
#  -- 영화이름 :  클로버-웨이베터 || 클로버-웨이베터 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['더', '선', '이', '샤'] :: ['드', '릭', '야', '스', '네', '즈', '헨'] --> []
# ['버', '클', "'", '미', '이', '다', '터', '로', '베', '니', '큐', '웨'] :: ['버', '클', '이', '터', '로', '베', '웨', '-'] --> ['버', '클', '이', '터', '로', '베', '웨']
#  -- 감독명 :  샤이더선 || 야네스헨드릭즈 --> 일치율:  0 %
#  -- 영화이름 :  클로버-웨이베터 || 클로버'웨이베터'미니다큐 --> 일치율:  58 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['세', '우', '로', '바', '실'] :: ['드', '릭', '야', '스', '네', '즈', '헨'] --> []
# ['버', '클', '이', '터', '로', '베', '웨'] :: ['버', '클', '이', '터', '로', '베', '웨', '-'] --> ['버', '클', '이', '터', '로', '베', '웨']
#  -- 감독명 :  세실바로우 || 야네스헨드릭즈 --> 일치율:  0 %
#  -- 영화이름 :  클로버-웨이베터 || 클로버웨이베터 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 380 클로버 - 웨이 베터  ->  {'배급사': '', '등급': '', '장르': '애니메이션', '배우': ''}
# --------------------------------------------------
#  -- 감독명 :  야노티카라 || 야노티카라 -->  일치율:  100 %
#  -- 영화이름 :  외로운미망인:시아버지와도련님 || 외로운미망인:시아버지와도련님 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 381 외로운 미망인:시아버지와 도련님  ->  {'배급사': '', '등급': '[국내] 청소년 관람불가', '장르': '일본', '배우': ''}
# --------------------------------------------------
#  -- 감독명 :  야노티카라 || 야노티카라 -->  일치율:  100 %
#  -- 영화이름 :  하고싶은형수님:형의선물 || 하고싶은형수님:형의선물 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 382 하고싶은 형수님:형의 선물  ->  {'배급사': '', '등급': '[국내] 청소년 관람불가', '장르': '일본', '배우': ''}
# --------------------------------------------------
# ['드', '헤', '이', '르', '폴', '야', '마', '키', '츠', '노', '니', '에', ','] :: ['헤', '이', '에', '폴', '르', '야', '마', '키', '노', '츠', '니', '드', ','] --> ['드', '헤', '이', '르', '폴', '야', '마', '키', '노', '츠', '니', '에', ',']
#  -- 감독명 :  헤이키에르니츠,야노폴드마 || 야노폴드마,헤이키에르니츠 -->  일치율:  100 %
#  -- 영화이름 :  로테와문스톤의비밀 || 로테와문스톤의비밀 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 383 로테와 문스톤의 비밀  ->  {'배급사': '', '등급': '', '장르': '애니메이션', '배우': '미크 저젠스,마이트 말름스텐,토누 오자'}
# --------------------------------------------------
# ['지', '오', '슌', '가'] :: ['히', '야', '키', '노', '로', '유'] --> []
#  -- 감독명 :  오오가슌지 || 야노히로유키 --> 일치율:  0 %
#  -- 영화이름 :  호빵맨과숲속의보물:노래부르며함께놀아요 || 호빵맨과숲속의보물:노래부르며함께놀아요 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 384 호빵맨과 숲속의 보물 : 노래 부르며 함께 놀아요  ->  {'배급사': '', '등급': '', '장르': '', '배우': ''}
# --------------------------------------------------
# 전처리데이터: 385 날아라! 호빵맨 극장판: 구하라! 코코링과 기적의 별  ->  {'배급사': '씨너스엔터테인먼트(주)', '등급': '전체관람가', '장르': '애니메이션', '배우': '토다 케이코,마츠유키 야스코,나카오 류세이'}
# --------------------------------------------------
# 전처리데이터: 386 극장판 날아라! 호빵맨 : 바나나섬을 되찾아줘  ->  {'배급사': '와이드 릴리즈(주)', '등급': '전체관람가', '장르': '애니메이션', '배우': '이선주,황원'}
# --------------------------------------------------
# 전처리데이터: 387 아르마딜로  ->  {'배급사': '(주)엣나인필름', '등급': '15세이상관람가', '장르': '전쟁', '배우': '매드 미니,다니엘 웰비,라스무스 문케,김 비르커뢰드'}
# --------------------------------------------------
# 전처리데이터: 388 보리 vs 매켄로  ->  {'배급사': '(주)엣나인필름', '등급': '12세이상관람가', '장르': '드라마', '배우': '스베리르 구드나손,샤이아 라보프,스텔란 스카스가드'}
# --------------------------------------------------
# 전처리데이터: 389 해적: 위대한 영웅  ->  {'배급사': '(주)블루브릭', '등급': '12세이상관람가', '장르': '어드벤처', '배우': '세바스티안 코치,후안 디에고 보토,까뜨린느 드뇌브,존 클리즈'}
# --------------------------------------------------
# 전처리데이터: 390 너무 밝히는 소녀 알마  ->  {'배급사': '(주)스크린와이즈', '등급': '청소년관람불가', '장르': '코미디', '배우': '헬레네 베르그스홀름,아서 베르닝'}
# --------------------------------------------------
# ['니', '레', '할', '린'] :: ['엘', '리', '야', '스', '크', '니', '플', '보', '즈'] --> ['니']
#  -- 감독명 :  레니할린 || 야니크스플리즈보엘 --> 일치율:  25 %
#  -- 영화이름 :  미스피츠 || 미스피츠 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
#  -- 감독명 :  야니크스플리즈보엘 || 야니크스플리즈보엘 -->  일치율:  100 %
#  -- 영화이름 :  미스피츠 || 미스피츠 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['그', '하', '이', '톰', '영', '나', '린', '퍼', '차', '무', ',', '-'] :: ['엘', '리', '야', '스', '크', '니', '플', '보', '즈'] --> []
# ['1', '미', '스', '츠', '핏'] :: ['미', '스', '피', '츠'] --> ['미', '스', '츠']
#  -- 감독명 :  톰그린,톰하퍼,차이나무-영 || 야니크스플리즈보엘 --> 일치율:  0 %
#  -- 영화이름 :  미스피츠 || 미스핏츠1 --> 일치율:  60 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['이', '피', '트', '터', '제', '로', '뉴', '드', ',', '프'] :: ['엘', '리', '야', '스', '크', '니', '플', '보', '즈'] --> []
# ['허', '적', '해', '단', '당'] :: ['미', '스', '피', '츠'] --> []
#  -- 감독명 :  피터로드,제프뉴이트 || 야니크스플리즈보엘 --> 일치율:  0 %
#  -- 영화이름 :  미스피츠 || 허당해적단 --> 일치율:  0 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 391 미스피츠  ->  {'배급사': '', '등급': '[국내] 전체 관람가', '장르': '다큐멘터리', '배우': ''}
# --------------------------------------------------
# 전처리데이터: 392 마지막 4중주  ->  {'배급사': '(주)티캐스트', '등급': '15세이상관람가', '장르': '드라마', '배우': '필립 세이모어 호프만,크리스토퍼 월켄,캐서린 키너,마크 이바니르'}
# --------------------------------------------------
# ['선', '영', '손'] :: ['바', '라', '리', '야'] --> []
#  -- 감독명 :  손영선 || 야리바라 --> 일치율:  0 %
#  -- 영화이름 :  생일 || 생일 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['종', '이', '언'] :: ['바', '라', '리', '야'] --> []
#  -- 감독명 :  이종언 || 야리바라 --> 일치율:  0 %
#  -- 영화이름 :  생일 || 생일 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['김', '율', '희'] :: ['바', '라', '리', '야'] --> []
#  -- 감독명 :  김율희 || 야리바라 --> 일치율:  0 %
#  -- 영화이름 :  생일 || 생일 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['상', '균', '박'] :: ['바', '라', '리', '야'] --> []
#  -- 감독명 :  박상균 || 야리바라 --> 일치율:  0 %
#  -- 영화이름 :  생일 || 생일 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['그', '티', '친', '룬', '스', '드', '렌'] :: ['바', '라', '리', '야'] --> []
#  -- 감독명 :  친티스룬드그렌 || 야리바라 --> 일치율:  0 %
#  -- 영화이름 :  생일 || 생일 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['자', '라', '리', '바'] :: ['바', '라', '리', '야'] --> ['라', '리', '바']
#  -- 감독명 :  바라자리 || 야리바라 -->  일치율:  75 %
#  -- 영화이름 :  생일 || 생일 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['지', '레', '엘', '나', '로', '바', '보'] :: ['바', '라', '리', '야'] --> ['바']
#  -- 감독명 :  엘레나보지로바 || 야리바라 --> 일치율:  14 %
#  -- 영화이름 :  생일 || 생일 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['지', '모', '데', '이', '르', '안', '긴', '파', '키', '네', ','] :: ['바', '라', '리', '야'] --> []
#  -- 감독명 :  데이지모르,네긴키안파르 || 야리바라 --> 일치율:  0 %
#  -- 영화이름 :  생일 || 생일 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
#  -- 감독명 :  None || 야리바라 --> 일치율:  0 %
#  -- 영화이름 :  생일 || 생일 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['리', '건'] :: ['바', '라', '리', '야'] --> ['리']
#  -- 감독명 :  리건 || 야리바라 --> 일치율:  50 %
#  -- 영화이름 :  생일 || 생일 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 393 생일  ->  {'배급사': '', '등급': '', '장르': '애니메이션', '배우': ''}
# --------------------------------------------------
#  -- 감독명 :  야리브모저 || 야리브모저 -->  일치율:  100 %
#  -- 영화이름 :  텔아비브의여름 || 텔아비브의여름 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 394 텔아비브의 여름  ->  {'배급사': '', '등급': '', '장르': '드라마', '배우': '리론 아르가만,야론 비톤,쉑 브레너'}
# --------------------------------------------------
#  -- 감독명 :  야마가타카유키 || 야마가타카유키 -->  일치율:  100 %
#  -- 영화이름 :  게발트파이브:구타본능 || 게발트파이브:구타본능 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 395 게발트 파이브:구타본능  ->  {'배급사': '(주) 영진크리에이티브', '등급': '[국내] 15세 관람가', '장르': '액션', '배우': ''}
# --------------------------------------------------
# 전처리데이터: 396 무림의 거유 여닌자 하즈키  ->  {'배급사': '(주)영진크리에이티브', '등급': '청소년관람불가', '장르': '멜로/로맨스', '배우': '사야마 아이'}
# --------------------------------------------------
#  -- 감독명 :  야마가타카유키 || 야마가타카유키 -->  일치율:  100 %
#  -- 영화이름 :  암살자사치-섹스해야사는여자 || 암살자사치-섹스해야사는여자 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 397 암살자 사치-섹스 해야 사는 여자  ->  {'배급사': '', '등급': '[국내] 청소년 관람불가', '장르': '멜로/로맨스', '배우': ''}
# --------------------------------------------------
# [':', '얄', '년', '2', '악', '신', '틀', '원', '소', '로', '배', '극'] :: [':', '얄', '년', '악', '신', '틀', '원', '소', '로', '배', '극'] --> [':', '얄', '년', '악', '신', '틀', '원', '소', '로', '배', '극']
#  -- 감독명 :  야마가타카유키 || 야마가타카유키 --> 일치율:  100 %
#  -- 영화이름 :  신배틀로얄:극악소년원 || 신배틀로얄:극악소년원2 --> 일치율:  91 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
#  -- 감독명 :  야마가타카유키 || 야마가타카유키 -->  일치율:  100 %
#  -- 영화이름 :  신배틀로얄:극악소년원 || 신배틀로얄:극악소년원 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 398 신 배틀로얄:극악 소년원  ->  {'배급사': '', '등급': '[국내] 청소년 관람불가', '장르': '액션', '배우': ''}
# --------------------------------------------------
#  -- 감독명 :  야마가타카유키 || 야마가타카유키 -->  일치율:  100 %
#  -- 영화이름 :  신배틀로얄:극악소년원2 || 신배틀로얄:극악소년원2 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 399 신 배틀로얄:극악 소년원2  ->  {'배급사': '', '등급': '[국내] 청소년 관람불가', '장르': '액션', '배우': ''}
# --------------------------------------------------
# 전처리데이터: 400 킬러본색: 블랙페이스  ->  {'배급사': '스크린조이', '등급': '청소년관람불가', '장르': '액션', '배우': '야마구치 요시유키'}
# --------------------------------------------------
# 전처리데이터: 401 닌자걸의 정사  ->  {'배급사': '(유)조이앤컨텐츠그룹', '등급': '청소년관람불가', '장르': '멜로/로맨스', '배우': '사야마 아이'}
# --------------------------------------------------
# 전처리데이터: 402 호스트걸의 비밀섹스  ->  {'배급사': '(유)조이앤컨텐츠그룹', '등급': '청소년관람불가', '장르': '멜로/로맨스', '배우': '나루세 코코미'}
# --------------------------------------------------
#  -- 감독명 :  야마가타카유키 || 야마가타카유키 -->  일치율:  100 %
#  -- 영화이름 :  특명:돈가방을찾아라 || 특명:돈가방을찾아라 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 403 특명:돈가방을 찾아라  ->  {'배급사': '', '등급': '[국내] 청소년 관람불가', '장르': '멜로/로맨스', '배우': '아에자와 리나,코가 미츠키'}
# --------------------------------------------------
# 전처리데이터: 404 야쿠자-피의 전쟁  ->  {'배급사': '퍼즐컷', '등급': '청소년관람불가', '장르': '액션', '배우': '하무라 에이'}
# --------------------------------------------------
#  -- 감독명 :  야마가히로유키 || 야마가히로유키 -->  일치율:  100 %
#  -- 영화이름 :  왕립우주군-오네아미스의날개 || 왕립우주군-오네아미스의날개 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 405 왕립우주군-오네아미스의 날개  ->  {'배급사': '', '등급': '', '장르': '애니메이션', '배우': '안자이 마사히로,모리모토 레오,시마다 빈'}
# --------------------------------------------------
# 전처리데이터: 406 극상 아로마마사지  ->  {'배급사': '(주)도키엔터테인먼트', '등급': '청소년관람불가', '장르': '성인물(에로)', '배우': '하츠미 사키,미즈미 사키'}
# --------------------------------------------------
# 전처리데이터: 407 오빠와 사랑하는 밤  ->  {'배급사': '(주)도키엔터테인먼트', '등급': '청소년관람불가', '장르': '성인물(에로)', '배우': '아베노 미쿠'}
# --------------------------------------------------
# 전처리데이터: 408 문열어! 요시미짱  ->  {'배급사': '페퍼민트픽쳐스', '등급': '청소년관람불가', '장르': '성인물(에로)', '배우': '아리무라 치카'}
# --------------------------------------------------
# 전처리데이터: 409 바람의 검 - 적영자  ->  {'배급사': '(주)빅웨이브시네마', '등급': '15세이상관람가', '장르': '액션', '배우': '칸이치로'}
# --------------------------------------------------
# 전처리데이터: 410 고양이 사무라이  ->  {'배급사': '어뮤즈', '등급': '12세이상관람가', '장르': '코미디', '배우': '키타무라 카즈키,카와무라 료스케,히라타 카오루'}
# --------------------------------------------------
# 전처리데이터: 411 하이앤로우 더 레드 레인  ->  {'배급사': '(주)엔케이컨텐츠', '등급': '청소년관람불가', '장르': '액션', '배우': '타카히로,토사카 히로오미,사이토 타쿠미'}
# --------------------------------------------------
# 전처리데이터: 412 베이블레이드 버스트 갓 : 갓 발키리의 탄생  ->  {'배급사': '(주)씨제이이엔엠', '등급': '전체관람가', '장르': '애니메이션', '배우': '김현지,한신,김보영,이호산,김영은'}
# --------------------------------------------------
# 전처리데이터: 413 극장판 기븐  ->  {'배급사': '(주)애니플러스', '등급': '15세이상관람가', '장르': '애니메이션', '배우': '야노 쇼고,우치다 유우마,나카자와 마사토모,에구치 타쿠야'}
# --------------------------------------------------
# 전처리데이터: 414 벌거벗은 옆집여자들  ->  {'배급사': '(주)영진크리에이티브', '등급': '청소년관람불가', '장르': '멜로/로맨스', '배우': '시노다 유우'}
# --------------------------------------------------
#  -- 감독명 :  야마다나오코 || 야마다나오코 -->  일치율:  100 %
#  -- 영화이름 :  케이온 || 케이온 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['온', '케', '이', '!'] :: ['온', '케', '이'] --> ['이', '케', '온']
#  -- 감독명 :  야마다나오코 || 야마다나오코 --> 일치율:  100 %
#  -- 영화이름 :  케이온 || 케이온! --> 일치율:  75 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 415 케이온  ->  {'배급사': '(주)에이원 엔터테인먼트', '등급': '[국내] 전체 관람가', '장르': '애니메이션', '배우': '토요사키 아키,히카사 요코,사토 사토미'}
# --------------------------------------------------
# 전처리데이터: 416 타마코 러브 스토리  ->  {'배급사': '주식회사 온 피크,(주)머스트씨무비릴리징컴퍼니', '등급': '전체관람가', '장르': '애니메이션', '배우': '스자키 아야,타마루 아츠시,카네코 유키'}
# --------------------------------------------------
#  -- 감독명 :  야마다나오코 || 야마다나오코 -->  일치율:  100 %
#  -- 영화이름 :  리즈와파랑새 || 리즈와파랑새 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 417 리즈와 파랑새  ->  {'배급사': '(주)디스테이션', '등급': '[국내] 전체 관람가', '장르': '애니메이션', '배우': '타네자키 아츠미,토우야마 나오,혼다 미유'}
# --------------------------------------------------
# 전처리데이터: 418 목소리의 형태  ->  {'배급사': '(주)디스테이션', '등급': '전체관람가', '장르': '애니메이션', '배우': '이리노 미유,하야미 사오리,유키 아오이,오노 켄쇼,카네코 유키,이시카와 유이,토요나가 토시유키'}
# --------------------------------------------------
#  -- 감독명 :  야마다마사후미 || 야마다마사후미 -->  일치율:  100 %
#  -- 영화이름 :  X게임2 || X게임2 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['피', '게', '임', '대', '소', '비', '동', '구', '무', 'X', '-'] :: ['2', '임', 'X', '게'] --> ['임', 'X', '게']
#  -- 감독명 :  None || 야마다마사후미 --> 일치율:  0 %
#  -- 영화이름 :  X게임2 || 구피무비-X게임대소동 --> 일치율:  27 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 419 X게임2  ->  {'배급사': '', '등급': '[국내] 청소년 관람불가', '장르': '공포', '배우': '오오타 아이카,히라지마 나츠미,유키 료이치'}
# --------------------------------------------------
# 전처리데이터: 420 개에게 처음 이름을 지어준 날  ->  {'배급사': '(주)퍼스트런,글뫼 주식회사', '등급': '전체관람가', '장르': '드라마', '배우': '코바야시 사토미,카미카와 타카야'}
# --------------------------------------------------
#  -- 감독명 :  야마다요지 || 야마다요지 -->  일치율:  100 %
#  -- 영화이름 :  작은집 || 작은집 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['미', '이', '야', '게', '타', '노', '니', '시'] :: ['지', '요', '다', '야', '마'] --> ['야']
#  -- 감독명 :  니시노미야게이타 || 야마다요지 --> 일치율:  12 %
#  -- 영화이름 :  작은집 || 작은집 --> 일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['뮐', '미', '리', '므', '퍼', '스', '크', '토', '렛', ',', '러'] :: ['지', '요', '다', '야', '마'] --> []
# ['산', '집', '것', '다', '는', '에', '작', '은'] :: ['작', '은', '집'] --> ['작', '은', '집']
#  -- 감독명 :  크리스토퍼스미스,므렛뮐러 || 야마다요지 --> 일치율:  0 %
#  -- 영화이름 :  작은집 || 작은집에산다는것 --> 일치율:  37 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# ['오', '카', '토', '니', '쿠'] :: ['지', '요', '다', '야', '마'] --> []
# ['집', '돌', '로', '쌓', '작', '은', '벽'] :: ['작', '은', '집'] --> ['작', '은', '집']
#  -- 감독명 :  카토쿠니오 || 야마다요지 --> 일치율:  0 %
#  -- 영화이름 :  작은집 || 작은벽돌로쌓은집 --> 일치율:  42 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 421 작은 집  ->  {'배급사': '', '등급': '[국내] 12세 관람가', '장르': '드라마', '배우': '마츠 다카코,바이쇼 치에코,쿠로키 하루'}
# --------------------------------------------------
#  -- 감독명 :  야마다요지 || 야마다요지 -->  일치율:  100 %
#  -- 영화이름 :  동경가족:두번째이야기 || 동경가족:두번째이야기 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 422 동경가족: 두 번째 이야기  ->  {'배급사': '', '등급': '', '장르': '코미디', '배우': '하시즈메 이사오,요시유키 카즈코,츠마부키 사토시'}
# --------------------------------------------------
# 전처리데이터: 423 동경가족  ->  {'배급사': '오드', '등급': '전체관람가', '장르': '가족', '배우': '하시즈메 이사오,요시유키 카즈코,츠마부키 사토시,아오이 유우,니시무라 마사히코,나츠카와 유이'}
# --------------------------------------------------
# 전처리데이터: 424 능숙한 아줌마-쾌락의 손기술  ->  {'배급사': '(주)영진크리에이티브', '등급': '청소년관람불가', '장르': '멜로/로맨스', '배우': '카자마 유미'}
# --------------------------------------------------
# 전처리데이터: 425 음탕한 여자-풍기는 밤꽃향기  ->  {'배급사': '(주)영진크리에이티브', '등급': '청소년관람불가', '장르': '멜로/로맨스', '배우': '혼다 미사키'}
# --------------------------------------------------
#  -- 감독명 :  야마다친 || 야마다친 -->  일치율:  100 %
#  -- 영화이름 :  형수:위험한취향 || 형수:위험한취향 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 426 형수:위험한 취향  ->  {'배급사': '', '등급': '[국내] 청소년 관람불가', '장르': '에로', '배우': ''}
# --------------------------------------------------
#  -- 감독명 :  야마다카즈야 || 야마다카즈야 -->  일치율:  100 %
#  -- 영화이름 :  푸지에 || 푸지에 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 427 푸지에  ->  {'배급사': '', '등급': '', '장르': '다큐멘터리', '배우': ''}
# --------------------------------------------------
#  -- 감독명 :  야마다하타루 || 야마다하타루 -->  일치율:  100 %
#  -- 영화이름 :  만취해서택시를탄여자들 || 만취해서택시를탄여자들 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 428 만취해서 택시를 탄 여자들  ->  {'배급사': '', '등급': '[국내] 청소년 관람불가', '장르': '에로', '배우': ''}
# --------------------------------------------------
#  -- 감독명 :  야마다후토시 || 야마다후토시 -->  일치율:  100 %
#  -- 영화이름 :  비밀섹스:발정난아내들 || 비밀섹스:발정난아내들 -->  일치율:  100 %
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 크롤링데이터: 429 비밀섹스:발정난 아내들  ->  {'배급사': '(주) 영진크리에이티브', '등급': '[국내] 청소년 관람불가', '장르': '멜로/로맨스', '배우': ''}
# --------------------------------------------------

# %%
df1 =pd.read_excel("Distributor20210804175633.xlsx")
df2 =pd.read_excel("Distributor20210804183643.xlsx")
df3 =pd.read_excel("Distributor20210804183700.xlsx")
df4 =pd.read_excel("Distributor20210804185723.xlsx")
df5 =pd.read_excel("Distributor20210804190418.xlsx")

df=pd.concat([df1,df2,df3,df4,df5])

# %%
df.to_csv("data5000_10000.csv",encoding = 'utf-8-sig')

# %%
count = 0 
for i in range(len(df_sum)):
    if type(df_sum.iloc[i]["배우"]) == float:
# Out:
# False
