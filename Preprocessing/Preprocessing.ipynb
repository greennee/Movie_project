# %%
import requests
from bs4 import BeautifulSoup
import time
import xlsxwriter as xlsxwriter
import csv
import math
import re
from datetime import datetime
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows',1000)

# %%
df_raw = pd.read_csv("크롤링_total.csv", index_col = False)
df_genne = pd.read_csv("genre.csv", index_col = False)
df_raw = pd.concat([df_raw, df_genne])
df = df_raw
df
# Out:
#              영화명         개봉일          매출액        누적매출액      관객수    누적관객수  \
# 0       태극기 휘날리며  2004-02-05  15687180500  15687180500  2544911  2544911
# 1            트로이  2004-05-21  12777346000  12777346000  2001293  2001293
# 2    내 머리 속의 지우개  2004-11-05  11919939500  11919939500  1885827  1885827
# 3         귀신이 산다  2004-09-17  11898748500  11898748500  1875936  1875936
# 4           투모로우  2004-06-03  11658584500  11658584500  1830767  1830767
# ..           ...         ...          ...          ...      ...      ...
# 670  너무 많이 본 사나이         NaN        80000        80000        8        8
# 671       파마하는 날         NaN         3200         3200        4        4
# 672       오리엔테이션         NaN       267500       267500      214      214
# 673       태양의 길목         NaN        85000        85000       17       17
# 674   쿠르쿠레 몬스터포즈         NaN        13066        13066       54       54
#
#      스크린수   상영횟수 대표국적               배급사      등급              장르        감독  \
# 0     115  22375   한국  (주)다자인소프트,(주)쇼박스  15세관람가          전쟁,드라마       강제규
# 1     177  21245   미국     워너브러더스 코리아(주)  15세관람가              사극   볼프강 페터젠
# 2     206  29532   한국            CJ ENM  12세관람가          멜로/로맨스       이재한
# 3     174  27936   한국         (주)시네마서비스  12세관람가  코미디,공포(호러),판타지       김상진
# 4     164  22881   미국     이십세기폭스필름코퍼레이션  12세관람가              SF  롤랜드 에머리히
# ..    ...    ...  ...               ...     ...             ...       ...
# 670     1      1   한국               NaN     NaN            장르없음       손재곤
# 671     1      1   한국               NaN     NaN            장르없음       송상현
# 672     1      4   한국               NaN     NaN            장르없음       송윤희
# 673     1      2   중국               NaN     NaN            장르없음       송태가
# 674     1      3   인도               NaN     NaN            장르없음  수레시 에리야트
#
#                                                     배우  Unnamed: 0
# 0    장동건,원빈,이은주,공형진,조원희,이장욱,이영란,정희준,박유신,김효열,김효준,최재혁...         NaN
# 1                                 다이앤 크루거,올랜도 블룸,에릭 바나         NaN
# 2    정우성,손예진,데이비드 맥기니스,김부선,정광재,최기호,박경진,장재용,전은희,이영필,...         NaN
# 3    김응수,장서희,차승원,김서현,최기웅,유대현,김성미,태인호,임상란,장승현,김정우,김양...         NaN
# 4                                 데니스 퀘이드,제이크 질렌할,이안 홈         NaN
# ..                                                 ...         ...
# 670                                                NaN       670.0
# 671                                                NaN       671.0
# 672                                                NaN       672.0
# 673                                                NaN       673.0
# 674                                                NaN       674.0
#
# [27233 rows x 15 columns]

# %%
df = df.loc[:, "영화명": "배우"]
df
# Out:
#              영화명         개봉일          매출액        누적매출액      관객수    누적관객수  \
# 0       태극기 휘날리며  2004-02-05  15687180500  15687180500  2544911  2544911
# 1            트로이  2004-05-21  12777346000  12777346000  2001293  2001293
# 2    내 머리 속의 지우개  2004-11-05  11919939500  11919939500  1885827  1885827
# 3         귀신이 산다  2004-09-17  11898748500  11898748500  1875936  1875936
# 4           투모로우  2004-06-03  11658584500  11658584500  1830767  1830767
# ..           ...         ...          ...          ...      ...      ...
# 670  너무 많이 본 사나이         NaN        80000        80000        8        8
# 671       파마하는 날         NaN         3200         3200        4        4
# 672       오리엔테이션         NaN       267500       267500      214      214
# 673       태양의 길목         NaN        85000        85000       17       17
# 674   쿠르쿠레 몬스터포즈         NaN        13066        13066       54       54
#
#      스크린수   상영횟수 대표국적               배급사      등급              장르        감독  \
# 0     115  22375   한국  (주)다자인소프트,(주)쇼박스  15세관람가          전쟁,드라마       강제규
# 1     177  21245   미국     워너브러더스 코리아(주)  15세관람가              사극   볼프강 페터젠
# 2     206  29532   한국            CJ ENM  12세관람가          멜로/로맨스       이재한
# 3     174  27936   한국         (주)시네마서비스  12세관람가  코미디,공포(호러),판타지       김상진
# 4     164  22881   미국     이십세기폭스필름코퍼레이션  12세관람가              SF  롤랜드 에머리히
# ..    ...    ...  ...               ...     ...             ...       ...
# 670     1      1   한국               NaN     NaN            장르없음       손재곤
# 671     1      1   한국               NaN     NaN            장르없음       송상현
# 672     1      4   한국               NaN     NaN            장르없음       송윤희
# 673     1      2   중국               NaN     NaN            장르없음       송태가
# 674     1      3   인도               NaN     NaN            장르없음  수레시 에리야트
#
#                                                     배우
# 0    장동건,원빈,이은주,공형진,조원희,이장욱,이영란,정희준,박유신,김효열,김효준,최재혁...
# 1                                 다이앤 크루거,올랜도 블룸,에릭 바나
# 2    정우성,손예진,데이비드 맥기니스,김부선,정광재,최기호,박경진,장재용,전은희,이영필,...
# 3    김응수,장서희,차승원,김서현,최기웅,유대현,김성미,태인호,임상란,장승현,김정우,김양...
# 4                                 데니스 퀘이드,제이크 질렌할,이안 홈
# ..                                                 ...
# 670                                                NaN
# 671                                                NaN
# 672                                                NaN
# 673                                                NaN
# 674                                                NaN
#
# [27233 rows x 14 columns]

# %% [markdown]
# ### 2. 중복값 제거

# %%
df = df.sort_values(["감독","누적관객수","누적매출액"], ascending=True)

# %%
df.drop_duplicates(['영화명',"감독"], keep = 'last',inplace=True)

# %%
df["영화명"].value_counts()
# Out:
# 로미오와 줄리엣          6
# 카르멘               6
# 토스카               6
# 욕망                5
# 돈                 4
#                  ..
# 아내의 동창회 2         1
# 온천에서 유혹하는 처제      1
# 매혹의 스캔들           1
# 굿 윌 헌팅            1
# 일본꽐라녀:달아오른 몸뚱이    1
# Name: 영화명, Length: 20749, dtype: int64

# %% [markdown]
# ### 3. 장르 전처리

# %%
df["장르"].value_counts()
# Out:
# 드라마                              4336
# 멜로/로맨스                           2038
# 다큐멘터리                            2001
# 애니메이션                            1811
# 액션                               1453
# 장르없음                             1282
# 코미디                              1026
# 에로                                943
# 성인물(에로)                           759
# 공포(호러)                            549
# 스릴러                               462
# 범죄                                366
# SF                                243
# 미스터리                              161
# 판타지                               132
# 공포                                132
# 공연                                129
# 전쟁                                126
# 가족                                 95
# 어드벤처                               82
# 모험                                 79
# 뮤지컬                                61
# 드라마,멜로/로맨스                         57
# 멜로/로맨스,코미디                         51
# 코미디,드라마                            47
# 서부                                 45
# 사극                                 43
# 공연실황                               43
# 멜로/로맨스,드라마                         42
# 공포(호러),스릴러                         36
# 드라마,코미디                            31
# 코미디,멜로/로맨스                         29
# 액션,코미디                             15
# 드라마,스릴러                            15
# 드라마,액션                             12
# 코미디,드라마,멜로/로맨스                     12
# 액션,드라마                             12
# 서부극(웨스턴)                           11
# 공포(호러),미스터리,스릴러                    10
# 느와르                                 9
# 애니메이션,코미디                           9
# 멜로/로맨스,드라마,코미디                      8
# 액션,범죄                               8
# 스릴러,액션                              8
# 가족,드라마                              8
# 무협                                  8
# 범죄,스릴러                              8
# 성인물(에로),드라마                         7
# 액션,어드벤처                             7
# 드라마,전쟁                              7
# 스릴러,드라마                             7
# 애니메이션,가족                            6
# 액션,스릴러,범죄                           6
# 스릴러,드라마,범죄                          5
# 코미디,범죄                              5
# 액션,드라마,범죄                           5
# 범죄,스릴러,액션                           5
# 애니메이션,코미디,어드벤처                      5
# 미스터리,드라마                            5
# 액션,SF                               5
# 코미디,액션                              5
# 애니메이션,어드벤처,가족                       5
# 범죄,드라마                              5
# 액션,스릴러                              5
# 드라마,코미디,멜로/로맨스                      5
# SF,액션                               5
# 미스터리,스릴러                            5
# 애니메이션,코미디,어드벤처,가족                   5
# 액션,어드벤처,판타지                         5
# 멜로/로맨스,판타지                          5
# 액션,범죄,스릴러                           5
# 범죄,드라마,스릴러                          5
# 드라마,가족                              5
# 드라마,범죄,스릴러                          4
# SF,스릴러,액션                           4
# 어드벤처,판타지                            4
# 액션,어드벤처,코미디                         4
# 드라마,멜로/로맨스,코미디                      4
# 공포(호러),드라마                          4
# SF,액션,어드벤처                          4
# 멜로/로맨스,액션                           4
# 전쟁,드라마                              4
# 드라마,사극                              4
# 드라마,미스터리                            4
# 코미디,드라마,범죄                          4
# 드라마,범죄,액션                           4
# 액션,판타지                              4
# 실험                                  4
# 공포(호러),드라마,스릴러                      4
# 범죄,액션                               4
# 드라마,성인물(에로)                         4
# SF,스릴러                              3
# 다큐멘터리,드라마                           3
# 드라마,미스터리,스릴러                        3
# 코미디,멜로/로맨스,판타지                      3
# 공포(호러),스릴러,범죄                       3
# 드라마,사극,전쟁                           3
# 드라마,코미디,가족                          3
# 코미디,멜로/로맨스,드라마                      3
# 스릴러,범죄                              3
# 드라마,범죄                              3
# 판타지,어드벤처                            3
# 액션,코미디,어드벤처,판타지                     3
# 서스펜스                                3
# 가족,어드벤처                             3
# 액션,드라마,스릴러                          3
# 애니메이션,액션                            3
# 코미디,판타지                             3
# SF,공포(호러),스릴러                       3
# 어드벤처,가족,판타지                         3
# 사극,멜로/로맨스                           3
# 애니메이션,어드벤처                          3
# 드라마,어드벤처                            2
# 애니메이션,코미디,어드벤처,SF                   2
# 액션,범죄,드라마                           2
# SF,액션,스릴러                           2
# 스릴러,멜로/로맨스                          2
# 공포(호러),SF,스릴러                       2
# 코미디,가족                              2
# SF,액션,판타지                           2
# 애니메이션,가족,판타지                        2
# 코미디,공포(호러)                          2
# 드라마,멜로/로맨스,액션                       2
# 범죄,스릴러,미스터리                         2
# 애니메이션,드라마                           2
# 범죄,공포(호러),스릴러                       2
# 드라마,멜로/로맨스,판타지                      2
# 드라마,미스터리,범죄                         2
# 서사                                  2
# SF,미스터리                             2
# 코미디,뮤지컬,판타지                         2
# 스릴러,애니메이션                           2
# 멜로/로맨스,코미디,드라마                      2
# 미스터리,공포(호러)                         2
# 멜로/로맨스,성인물(에로),코미디                  2
# SF,어드벤처,판타지                         2
# 애니메이션,어드벤처,SF                       2
# 스릴러,드라마,미스터리                        2
# 드라마,코미디,판타지                         2
# 어드벤처,드라마                            2
# 다큐멘터리,액션                            2
# 스릴러,액션,어드벤처                         2
# 멜로/로맨스,스릴러                          2
# SF,드라마,액션                           2
# 멜로/로맨스,액션,판타지                       2
# 드라마,범죄,미스터리                         2
# 뮤지컬,코미디                             2
# 범죄,코미디                              2
# SF,액션,범죄                            2
# 코미디,스릴러                             2
# 어드벤처,가족                             2
# 액션,드라마,어드벤처                         2
# 애니메이션,SF                            2
# 애니메이션,코미디,가족                        2
# 애니메이션,어드벤처,판타지,액션                   2
# 드라마,스릴러,범죄                          2
# 드라마,액션,범죄                           2
# 액션,공포(호러),SF,스릴러                    2
# 드라마,어드벤처,코미디                        2
# 공포(호러),스릴러,코미디                      2
# 액션,범죄,코미디                           2
# 코미디,어드벤처                            2
# 코미디,가족,판타지                          2
# 코미디,어드벤처,가족                         2
# SF,드라마,스릴러                          2
# 전쟁,드라마,액션                           2
# 판타지,드라마                             2
# 액션,멜로/로맨스                           2
# 코미디,드라마,판타지                         2
# 다큐멘터리,어드벤처                          2
# 범죄,드라마,미스터리,스릴러                     2
# 애니메이션,코미디,어드벤처,가족,판타지               2
# 액션,스릴러,미스터리                         2
# 드라마,멜로/로맨스,스릴러                      2
# 애니메이션,드라마,판타지,코미디                   1
# 사극,드라마,스릴러                          1
# 드라마,스릴러,범죄,코미디                      1
# 코미디,멜로/로맨스,SF                       1
# 스릴러,액션,판타지                          1
# 액션,공포(호러),판타지,SF                    1
# 성인물(에로),코미디                         1
# 애니메이션,코미디,액션,SF,범죄                  1
# 드라마,미스터리,사극,코미디                     1
# 드라마,액션,스릴러,판타지                      1
# 공포(호러),스릴러,미스터리                     1
# 공포(호러),스릴러,판타지                      1
# SF,드라마,어드벤처,판타지                     1
# 애니메이션,가족,코미디                        1
# SF,액션,코미디                           1
# 드라마,멜로/로맨스,스릴러,미스터리                 1
# 액션,어드벤처,드라마,스릴러,서부극(웨스턴)            1
# 코미디,드라마,가족                          1
# 애니메이션,SF,어드벤처                       1
# 사극,액션,코미디                           1
# 액션,코미디,어드벤처,전쟁                      1
# 액션,가족                               1
# SF,드라마,어드벤처                         1
# 액션,드라마,전쟁                           1
# 멜로/로맨스,범죄                           1
# 액션,드라마,가족,범죄                        1
# 공포(호러),멜로/로맨스                       1
# 어드벤처,드라마,가족,판타지                     1
# 액션,드라마,범죄,스릴러                       1
# 애니메이션,가족,SF,어드벤처                    1
# 스릴러,드라마,액션                          1
# 액션,드라마,판타지                          1
# 가족,코미디,드라마                          1
# 사극,드라마,액션,전쟁                        1
# 뮤지컬,드라마,코미디                         1
# 드라마,공포(호러)                          1
# 가족,애니메이션,어드벤처                       1
# 어드벤처,판타지,드라마                        1
# SF,어드벤처,가족,액션                       1
# SF,스릴러,드라마                          1
# 드라마,멜로/로맨스,뮤지컬                      1
# 공포(호러),스릴러,어드벤처                     1
# 멜로/로맨스,드라마,전쟁                       1
# 액션,SF,판타지                           1
# 스릴러,미스터리                            1
# 사극,드라마                              1
# 애니메이션,액션,어드벤처                       1
# 애니메이션,드라마,액션,가족                     1
# 어드벤처,스릴러                            1
# 애니메이션,어드벤처,가족,SF                    1
# 드라마,멜로/로맨스,미스터리                     1
# 스릴러,공포(호러)                          1
# 사극,액션                               1
# 애니메이션,코미디,어드벤처,가족,SF                1
# 멜로/로맨스,드라마,뮤지컬                      1
# 액션,어드벤처,가족                          1
# 가족,멜로/로맨스,코미디,판타지                   1
# 코미디,공포(호러),판타지                      1
# 드라마,공포(호러),미스터리,스릴러                 1
# 드라마,코미디,멜로/로맨스,가족                   1
# 판타지,액션,어드벤처,드라마                     1
# 판타지,어드벤처,가족                         1
# 코미디,서부극(웨스턴)                        1
# 애니메이션,액션,가족,스릴러                     1
# 멜로/로맨스,드라마,판타지                      1
# 뮤지컬,드라마,멜로/로맨스                      1
# 애니메이션,판타지,SF                        1
# 애니메이션,어드벤처,SF,코미디                   1
# SF,드라마,액션,스릴러                       1
# 가족,어드벤처,액션                          1
# 애니메이션,코미디,드라마                       1
# 판타지,드라마,멜로/로맨스                      1
# 판타지,코미디,드라마                         1
# 스릴러,미스터리,공포(호러)                     1
# 가족,코미디,판타지                          1
# 애니메이션,드라마,가족,판타지                    1
# 가족,어드벤처,애니메이션                       1
# 애니메이션,미스터리,범죄                       1
# 사극,드라마,액션,멜로/로맨스,판타지                1
# 드라마,전쟁,미스터리                         1
# SF,코미디,판타지                          1
# 어드벤처,판타지,가족                         1
# 미스터리,코미디                            1
# 공포(호러),액션                           1
# 다큐멘터리,코미디                           1
# 스릴러,판타지,사극                          1
# 애니메이션,코미디,액션                        1
# 코미디,드라마,판타지,멜로/로맨스                  1
# 판타지,드라마,액션,스릴러                      1
# 액션,미스터리,판타지,SF                      1
# 멜로/로맨스,드라마,코미디,가족                   1
# 애니메이션,코미디,드라마,어드벤처                  1
# 드라마,애니메이션                           1
# SF,액션,판타지,드라마                       1
# 드라마,액션,판타지,어드벤처                     1
# 범죄,액션,스릴러,어드벤처                      1
# 액션,어드벤처,SF                          1
# SF,어드벤처,코미디                         1
# 스릴러,액션,드라마,미스터리                     1
# 판타지,가족,어드벤처                         1
# 멜로/로맨스,액션,어드벤처,스릴러                  1
# 액션,어드벤처,스릴러                         1
# 액션,드라마,코미디                          1
# 드라마,전쟁,액션                           1
# 공포(호러),코미디                          1
# 미스터리,스릴러,사극,범죄                      1
# 애니메이션,어드벤처,판타지                      1
# 코미디,멜로/로맨스,스릴러                      1
# 공포(호러),드라마,스릴러,미스터리                 1
# 애니메이션,멜로/로맨스                        1
# 판타지,스릴러                             1
# 코미디,드라마,액션                          1
# 어드벤처,코미디,액션                         1
# 액션,가족,판타지,어드벤처                      1
# 범죄,액션,드라마                           1
# 애니메이션,코미디,뮤지컬                       1
# 공포(호러),코미디,애니메이션                    1
# 드라마,멜로/로맨스,미스터리,코미디                 1
# 공포(호러),미스터리,범죄                      1
# SF,드라마,멜로/로맨스                       1
# 애니메이션,액션,스릴러,미스터리,어드벤처,판타지,SF       1
# 공포(호러),액션,드라마,범죄                    1
# 코미디,액션,미스터리,범죄                      1
# 애니메이션,코미디,가족,어드벤처                   1
# 코미디,판타지,어드벤처,가족                     1
# 어드벤처,코미디,스릴러                        1
# 가족,드라마,액션                           1
# 가족,어드벤처,판타지                         1
# 애니메이션,코미디,판타지                       1
# 드라마,어드벤처,멜로/로맨스                     1
# 공포(호러),액션,판타지                       1
# 멜로/로맨스,미스터리,범죄,스릴러                  1
# 공포(호러),액션,스릴러                       1
# 액션,코미디,드라마                          1
# 판타지,액션,어드벤처                         1
# 미스터리,스릴러,드라마                        1
# 액션,공포(호러),스릴러                       1
# 액션,스릴러,드라마                          1
# 액션,코미디,멜로/로맨스                       1
# SF,드라마                              1
# SF,미스터리,어드벤처                        1
# 범죄,드라마,코미디                          1
# 범죄,멜로/로맨스,스릴러                       1
# 멜로/로맨스,드라마,애니메이션                    1
# 뮤지컬,공연                              1
# 코미디,드라마,성인물(에로)                     1
# 액션,어드벤처,SF,가족                       1
# 스릴러,어드벤처,공포(호러)                     1
# 스릴러,드라마,공포(호러),멜로/로맨스               1
# 범죄,액션,코미디                           1
# 애니메이션,판타지                           1
# 액션,코미디,공포(호러),SF                    1
# 애니메이션,드라마,액션,어드벤처                   1
# 미스터리,범죄,스릴러                         1
# 코미디,액션,드라마,범죄                       1
# 코미디,액션,멜로/로맨스                       1
# 어드벤처,액션,가족                          1
# 드라마,미스터리,범죄,스릴러                     1
# 스릴러,드라마,전쟁                          1
# 뮤지컬,범죄,스릴러                          1
# 가족,드라마,멜로/로맨스                       1
# 드라마,스릴러,액션                          1
# 멜로/로맨스,어드벤처,코미디                     1
# SF,액션,미스터리,드라마                      1
# 스릴러,판타지                             1
# 액션,사극                               1
# 코미디,액션,범죄                           1
# 범죄,서부극(웨스턴),액션                      1
# 판타지,드라마,액션,어드벤처                     1
# 드라마,기타                              1
# 액션,스릴러,SF                           1
# SF,액션,판타지,가족                        1
# 액션,판타지,SF                           1
# 미스터리,드라마,스릴러                        1
# SF,드라마,미스터리                         1
# 미스터리,드라마,범죄                         1
# 드라마,뮤지컬,코미디                         1
# 드라마,판타지                             1
# 액션,스릴러,SF,어드벤처                      1
# 액션,드라마,멜로/로맨스                       1
# 코미디,액션,가족                           1
# 미스터리,스릴러,범죄                         1
# 드라마,범죄,코미디                          1
# 성인물(에로),공포(호러)                      1
# 뮤지컬,코미디,공포(호러)                      1
# 범죄,스릴러,드라마                          1
# 다큐멘터리,어드벤처,드라마,전쟁                   1
# 애니메이션,액션,어드벤처,SF                    1
# 스릴러,드라마,범죄,액션                       1
# 스릴러,어드벤처                            1
# 애니메이션,어드벤처,가족,판타지,미스터리              1
# SF,공포(호러),드라마                       1
# 드라마,멜로/로맨스,전쟁                       1
# SF,액션,스릴러,드라마,코미디                   1
# 애니메이션,어드벤처,가족,액션                    1
# 가족,뮤지컬                              1
# 애니메이션,액션,코미디                        1
# 드라마,액션,사극                           1
# 멜로/로맨스,액션,코미디                       1
# 코미디,공포(호러),뮤지컬                      1
# 애니메이션,미스터리                          1
# 애니메이션,액션,가족                         1
# 범죄,코미디,액션,스릴러                       1
# 액션,코미디,공포(호러)                       1
# 애니메이션,어드벤처,가족,드라마                   1
# 범죄,공포(호러)                           1
# SF,미스터리,스릴러                         1
# 액션,코미디,스릴러,범죄                       1
# 드라마,액션,코미디                          1
# 애니메이션,드라마,액션,SF                     1
# 판타지,액션,스릴러,SF                       1
# 스릴러,성인물(에로)                         1
# 액션,스릴러,어드벤처                         1
# 멜로/로맨스,미스터리                         1
# 액션,전쟁,드라마,사극                        1
# 액션,코미디,범죄                           1
# 액션,SF,스릴러                           1
# 애니메이션,드라마,어드벤처,판타지                  1
# 코미디,드라마,멜로/로맨스,뮤지컬,가족               1
# 코미디,드라마,멜로/로맨스,범죄,어드벤처,가족           1
# 어드벤처,코미디                            1
# 코미디,드라마,멜로/로맨스,가족                   1
# 사극,드라마,멜로/로맨스                       1
# 액션,공포(호러),SF                        1
# 코미디,드라마,스릴러                         1
# 드라마,코미디,미스터리                        1
# 애니메이션,가족,드라마                        1
# 드라마,멜로/로맨스,서부극(웨스턴)                 1
# 코미디,판타지,멜로/로맨스                      1
# 드라마,가족,어드벤처                         1
# 드라마,뮤지컬                             1
# 공포(호러),드라마,미스터리                     1
# 액션,드라마,사극                           1
# 공포(호러),스릴러,액션                       1
# 어드벤처,멜로/로맨스,판타지,애니메이션               1
# 판타지,어드벤처,미스터리                       1
# 애니메이션,드라마,멜로/로맨스,판타지                1
# 가족,코미디,액션                           1
# 판타지,액션,어드벤처,SF                      1
# Name: 장르, dtype: int64

# %%
## nan값 확인 후 처리
df["장르"].isnull().sum() #결측값 2396
# Out:
# 1844

# %%
df.tail()
# Out:
#                                영화명         개봉일      매출액    누적매출액  관객수  누적관객수  \
# 20309                      댄싱 인 자파         NaN    88000    88000   15     15
# 23238                  위기의 30대 여자들         NaN   946400   946400  136    136
# 20310                   16세의 사운드트랙  2020-07-02  3543400  3543400  413    413
# 2785   나의 말을 지켜봐: 어느 귀 먼 연예인들의 이야기         NaN   293500   293500  114    114
# 20311                       분노의 건샷  2016-12-14     4000     4000    1      1
#
#        스크린수  상영횟수  대표국적          배급사            등급     장르         감독  \
# 20309     1     2    미국          NaN           NaN  다큐멘터리    힐라 메달리아
# 23238     1     2  이스라엘          NaN           NaN  다큐멘터리    힐라 메달리아
# 20310    19   150    영국  (주)마노엔터테인먼트      12세이상관람가    코미디  힐러리 셰익스피어
# 2785      1     2    미국          NaN           NaN  다큐멘터리     힐러리 스칼
# 20311     1     1    미국    (주) 케이알씨지  [국내] 15세 관람가     범죄   힐러리안 뱅크스
#
#                                  배우
# 20309                           NaN
# 23238                           NaN
# 20310               제임스 캘로웨이,스칼렛 마셜
# 2785                            NaN
# 20311  제임스 와일더,조아큄 드 알메이다,레베카 메이 파머

# %%
df.reset_index(inplace=True)

# %%
for i in range(len(df["장르"])):
    if type(df["장르"][i]) == float:
        df["장르"][i] = "장르없음"
    else:
        df["장르"][i] = df["장르"][i].split(",")[0]
# Out:
# <ipython-input-390-ce42fc033b6c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["장르"][i] = df["장르"][i].split(",")[0]
# <ipython-input-390-ce42fc033b6c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["장르"][i] = "장르없음"

# %%
# 카테고리 만들기

df.replace("성인물(에로)", "에로", inplace = True)
df.replace("서부극(웨스턴)", "서부", inplace = True)
df.replace("공연실황", "공연", inplace = True)
df.replace("서스펜스", "스릴러", inplace = True)
df.replace("공포(호러)", "공포", inplace = True)
df.replace("멜로/로맨스", "멜로로맨스", inplace = True)
df.replace("실험", "다큐멘터리", inplace = True)

# %%
#기타장르 제거
guitar_idx = df[df["장르"]=="기타"].index
df.drop(guitar_idx, inplace=True)

# %%
df["장르"].value_counts()
# Out:
# 드라마      4552
# 장르없음     3126
# 멜로로맨스    2167
# 다큐멘터리    2014
# 애니메이션    1899
# 에로       1711
# 액션       1586
# 코미디      1173
# 공포        756
# 스릴러       510
# 범죄        410
# SF        294
# 미스터리      180
# 공연        172
# 판타지       149
# 전쟁        132
# 가족        117
# 어드벤처      102
# 모험         79
# 뮤지컬        68
# 서부         56
# 사극         53
# 느와르         9
# 무협          8
# 서사          2
# Name: 장르, dtype: int64

# %% [markdown]
# ### 4. 매출액  / 누적매출액 : 음수 -> 양수

# %%
values = []

for value in df['매출액'].values:
    value = abs(value)
    values.append(value)

# %%
stacked_values = []

for value in df['누적매출액'].values:
    value = abs(value)
    stacked_values.append(value)

# %%
# df['매출액'] = values
# df['누적매출액'] = stacked_values

# %% [markdown]
# ### 5. 등급 전처리

# %%
# 등급에서 "[국내] " 없애기
df['등급'].value_counts()

#df.replace("성인물(에로)", "에로", inplace = True)
df.replace([" 청소년 관람불가 ","청소년 관람불가 ","청소년 관람불가","[국내] 청소년 관람불가","고등학생이상관람가,청소년관람불가","청소년관람불가,12세관람가","국민학생관람불가,청소년관람불가","청소년관람불가,고등학생이상관람가","18세관람가,청소년관람불가","18세 미만인 자는 관람할 수 없는 등급","미성년자관람불가",'18세관람가', "연소자관람불가","연소자관람불가,청소년관람불가"], '청소년관람불가',inplace=True)
df.replace([" 15세 관람가 ","15세 관람가 ","[국내] 15세 관람가"," 15세 관람가","15세관람가","고등학생이상관람가","고등학생이상관람가,15세이상관람가","15세 미만인 자는 관람할 수 없는 등급","15세관람가,15세이상관람가","15세이상관람가,중학생이상관람가","15세이상관람가,미성년자관람불가","청소년관람불가,15세이상관람가","연소자관람불가,15세이상관람가","국민학생관람불가,15세이상관람가","15세이상관람가,전체관람가","15세이상관람가,18세 미만인 자는 관람할 수 없는 등급","연소자관람가,15세이상관람가","18세관람가,15세이상관람가","15세 미만인 자는 관람할 수 없는 등급 ,15세이상관람가"], '15세이상관람가',inplace=True)
df.replace([" 12세 관람가 ","12세 관람가 "," 12세 관람가","[국내] 12세 관람가","12세관람가","중학생이상관람가","국민학생관람불가","12세이상관람가,12세관람가","12세 미만인 자는 관람할 수 없는 등급","12세이상관람가,중학생이상관람가","12세이상관람가,국민학생관람불가","12세이상관람가,전체관람가","12세이상관람가,15세 미만인 자는 관람할 수 없는 등급","12세이상관람가,15세이상관람가","12세이상관람가,고등학생이상관람가","12세이상관람가,국민학생관람불가,15세이상관람가","12세이상관람가,연소자관람가","15세관람가,12세이상관람가"],"12세이상관람가", inplace=True)
df.replace(["전체관람가,중학생이상관람가"," 전체 관람가 ","전체 관람가 ","[국내] 전체 관람가","연소자관람가","모든 관람객이 관람할 수 있는 등급","연소자관람가,전체관람가","청소년관람불가,전체관람가","미성년자관람가","모든 관람객이 관람할 수 있는 등급,전체관람가","12세이상관람가,연소자관람가,전체관람가"],"전체관람가",inplace=True)

# %%
df["등급"].value_counts()
# Out:
# 청소년관람불가     6316
# 15세이상관람가    3887
# 12세이상관람가    2173
# 전체관람가       1889
# Name: 등급, dtype: int64

# %% [markdown]
# ### 6. 감독, 배우, 배급사

# %%
# 감독, 배우, 배급사 결측값 0으로 처리

df['배우'] = df['배우'].fillna(0)
df['감독'] = df['감독'].fillna(0)
df['배급사'] = df['배급사'].fillna(0)
df['등급'] = df['등급'].fillna("등급없음")

# %%
del df['index']

# %%
df
# Out:
#                                영화명         개봉일      매출액    누적매출액  관객수  누적관객수  \
# 0          416 프로젝트 "공동의 기억: 트라우마"         NaN  2192500  2192500  437    437
# 1                     미씨카: 더 네크로맨서  2017-11-02   300000   300000   60     60
# 2                     월드 워 핵전쟁의 서막  2019-03-07    26000    26000   17     17
# 3                            울프라이징  2016-11-17   300000   300000   60     60
# 4                  제3의앵글 : 형형색색대만전         NaN  1830000  1830000  305    305
# ...                            ...         ...      ...      ...  ...    ...
# 21320                      댄싱 인 자파         NaN    88000    88000   15     15
# 21321                  위기의 30대 여자들         NaN   946400   946400  136    136
# 21322                   16세의 사운드트랙  2020-07-02  3543400  3543400  413    413
# 21323  나의 말을 지켜봐: 어느 귀 먼 연예인들의 이야기         NaN   293500   293500  114    114
# 21324                       분노의 건샷  2016-12-14     4000     4000    1      1
#
#        스크린수  상영횟수  대표국적               배급사        등급     장르            감독  \
# 0         3    17    한국                 0      등급없음  다큐멘터리  416연대 미디어위원회
# 1         1     1    미국  (주)제이에이와이이엔터테인먼트  15세이상관람가    판타지     A. 토드 스미스
# 2         5    17  뉴질랜드           (주)풍경소리  15세이상관람가     액션      A.K. 스트롬
# 3         1     1    미국       주식회사 루믹스미디어  15세이상관람가     공포        BC 퍼트니
# 4         1     2    대만                 0      등급없음   장르없음          BITO
# ...     ...   ...   ...               ...       ...    ...           ...
# 21320     1     2    미국                 0      등급없음  다큐멘터리       힐라 메달리아
# 21321     1     2  이스라엘                 0      등급없음  다큐멘터리       힐라 메달리아
# 21322    19   150    영국       (주)마노엔터테인먼트  12세이상관람가    코미디     힐러리 셰익스피어
# 21323     1     2    미국                 0      등급없음  다큐멘터리        힐러리 스칼
# 21324     1     1    미국         (주) 케이알씨지  15세이상관람가     범죄      힐러리안 뱅크스
#
#                                  배우
# 0                                 0
# 1               애덤 존슨,로버트 제인,케빈 소르보
# 2            모건 브래들리,그레이엄 빈센트,캠벨 루셀
# 3                        빌 오버스트 주니어
# 4                                 0
# ...                             ...
# 21320                             0
# 21321                             0
# 21322               제임스 캘로웨이,스칼렛 마셜
# 21323                             0
# 21324  제임스 와일더,조아큄 드 알메이다,레베카 메이 파머
#
# [21325 rows x 14 columns]

# %% [markdown]
# ### 7. 대표국적

# %%
nation = ["미국", "한국", "일본", "프랑스", "영국", "독일", "중국", "이탈리아", "캐나다", "스페인"]

for i in range(len(df)):
    if df.iloc[i]["대표국적"] not in nation:
        df.replace(df.iloc[i]["대표국적"],"기타",inplace=True)

# %%
# nation = ["미국", "한국", "일본", "프랑스", "영국", "독일", "중국", "이탈리아", "캐나다", "스페인"]

# for i in df["대표국적"]:
#     if i not in nation:
#         i.replace(i,"기타",inplace=True)

# %%
df.head(100)
# Out:
#     index                        영화명         개봉일         매출액       누적매출액  \
# 0   23682    416 프로젝트 "공동의 기억: 트라우마"         NaN     2192500     2192500
# 1   22580               미씨카: 더 네크로맨서  2017-11-02      300000      300000
# 2    3092               월드 워 핵전쟁의 서막  2019-03-07       26000       26000
# 3    3093                      울프라이징  2016-11-17      300000      300000
# 4    3094            제3의앵글 : 형형색색대만전         NaN     1830000     1830000
# 5   21171                연쇄살인마의 이중생활  2020-06-18       16000       16000
# 6   20514                   몬스터 아일랜드  2017-10-27        3000        3000
# 7    3095           잃어버린 세계를 찾아 2015  2015-12-03        4000        4000
# 8    3096                과부: 탐스러운 육체  2016-11-19        5000        5000
# 9    3097                   페이스트리의 왕         NaN      642000      642000
# 10  20795                   지옥행 특급택시  2020-01-27        6000        6000
# 11  22589                텔미 하우 아이 다이  2017-09-28      300000      300000
# 12   3098                      스탠딩 업  2015-09-24        5000        5000
# 13    145                   테이킹 라이브즈  2004-04-15   249467500   249467500
# 14   3099                 트리플 엑스 리턴즈  2017-02-08  -327632201  -327632201
# 15   1246                      디스터비아  2007-08-30 -2147483648 -2147483648
# 16   3100                  아이 엠 넘버 포  2011-02-24   660248204   660248204
# 17   1149                      이글 아이  2008-10-09 -2147483648 -2147483648
# 18   3101                        레커스  2014-04-03    16066000    16066000
# 19   3102                    동쪽 저 멀리         NaN      160000      160000
# 20  20556                      겟 어웨이  2016-12-23        5000        5000
# 21   3103                  뱀파이어의 그림자         NaN      101500      101500
# 22    777                    서스펙트 제로  2005-03-17    28196000    28196000
# 23   3104                     네고시에이터  1998-10-24       57000       57000
# 24    699                          쿨  2005-04-08   136647000   136647000
# 25   3105             스트레이트 아웃 오브 컴턴  2015-09-10   412749800   412749800
# 26   2274                       모범시민  2009-12-10 -2147483648 -2147483648
# 27   3106              맨 인 블랙: 인터내셔널  2019-06-12 -1125725022 -1125725022
# 28   3107             분노의 질주: 더 익스트림  2017-04-12    63421000   -20193724
# 29   3108                      노스페라투         NaN      750000      750000
# 30   3109                         터부         NaN      246000      584000
# 31   3110                       선라이즈         NaN      133000     2837000
# 32   3111                      농부의 딸  1949-02-17      326000      326000
# 33   3112                        상간녀  2016-08-26      270000      270000
# 34   3113             여닌자:음기로 가득찬 자매  2018-05-28        6000        6000
# 35   3114                      제 5침공  2016-02-25  1041049900  1041049900
# 36  23452                       노예반란         NaN      436000      436000
# 37  23453                    맥켄나의 황금         NaN      184000      497000
# 38   3115                      태양의 왕         NaN      235000      802000
# 39   3116                     케이프 피어         NaN       72000     2326000
# 40   3117                       페세이지  1979-07-05     1924000     5596000
# 41   3118                     나바론 요새  1974-07-20     4228000    23458104
# 42   3119                     대장 부리바  1973-06-29     1290000    28200000
# 43  20377                   데스 에브리데이  2019-09-06        1000        1000
# 44   3120         마진 콜: 24시간, 조작된 진실  2013-01-03    46371500    50779500
# 45   3121                  모스트 바이어런트  2015-04-02    79886925    79886925
# 46   3122                   올 이즈 로스트  2013-11-07   102751500   102751500
# 47   3123                     슈퍼 에이트  2011-06-16  -671828796  -671828796
# 48   3124         스타워즈: 라이즈 오브 스카이워커  2020-01-08   417934914   417934914
# 49   3125               스타 트렉: 더 비기닝  2009-05-07     1660000 -1340376092
# 50   3126                  스타트렉 다크니스  2013-05-30   101787612   101787612
# 51   3127               스타워즈: 깨어난 포스  2015-12-17 -1710974741 -1710974741
# 52   3128                  미션 임파서블 3  2006-05-03      318000  2090430328
# 53   3129              백악기 꼬마공룡을 찾아서         NaN      350000      350000
# 54   3130                         필스  2013-11-21     6434000     6434000
# 55   3131               헬벤더스: 최후의 성전  2014-05-01     3792000     3792000
# 56   3132                    맛있는 유부녀  2019-03-06        6000        6000
# 57   3133                    섹스 주식회사  2012-09-27      190000      190000
# 58   3134                   좀비 vs 헌터  2018-01-11        2000        2000
# 59  20532                 터미네이터 사이보그  2018-02-02        3000        3000
# 60  20487  매일 밤 엿보기: 대놓고 보여주는 불륜 유부녀  2020-10-02        2000        2000
# 61  20638           가질 수 없는 첫사랑 가정교사  2020-03-28        6000        6000
# 62   3135                  아내의 아르바이트  2017-08-30        6000        6000
# 63  22903                 시체를 다루는 방법         NaN       80200       80200
# 64  23890                 웨이크필드 프로젝트  2020-06-08    17811000    17811000
# 65   3136                      더 비지트  2015-10-15   403435581   403435581
# 66    602                 레이디 인 더 워터  2006-10-13   675177000   675177000
# 67   1286                        해프닝  2008-06-12 -2147483648 -2147483648
# 68     55                        빌리지  2004-09-24  2507016000  2507016000
# 69   3137                        글래스  2019-01-17   -17514314   -17514314
# 70   3138                     애프터 어스  2013-05-30  -463111129  -463111129
# 71   2241                   라스트 에어벤더  2010-08-19 -2147483648 -2147483648
# 72   3139                   23 아이덴티티  2017-02-22     1728000   726474247
# 73   3140                   행복까지 30일  2016-06-09      500000    20249700
# 74   3141                       6솔져스  2019-05-29        1000        1000
# 75   3142                         로그  2020-11-25    31203140    31203140
# 76   2417                     솔로몬 케인  2010-03-25   940027000   940027000
# 77   3143               카마수트라: 뱀의 여인  2016-06-01      213000      213000
# 78   3144                  잔다라 더 피날레  2014-05-01    11852000    11852000
# 79   3145                 잔다라: 더 비기닝  2013-09-05    17946000    17946000
# 80   3146              욕구불만 유부녀의 장난감  2017-01-20        5000        5000
# 81   3147                      김정일리아  2011-06-23    10618000    10618000
# 82   3148                   사토미를 찾아라  2014-10-16    13164000    13164000
# 83  23821                  타임 이즈 일매틱         NaN    17046052    17046052
# 84   3149               때리지 말아요, 제발!         NaN       18000       18000
# 85   1110                     스나이퍼 3  2005-02-24       11000       11000
# 86   3150                     줄리아 엑스  2013-07-16      827000      827000
# 87   3151                    뮤리엘의 웨딩  1995-05-20       65000       65000
# 88     90                       피터 팬  2004-01-16   850564000   850564000
# 89   2347                       쇼퍼홀릭  2009-03-26  2073278500  2073278500
# 90   3152                        아버지         NaN      752000      752000
# 91   3153                         상자         NaN        2066        2066
# 92   3154                         럼블  2017-08-22        5000        5000
# 93   3155                       멕시칸잡  2017-05-18        5000        5000
# 94   3156                      미스파이어  2017-07-27        5000        5000
# 95   3157                     크로스 라인  2013-04-05     1350000     1350000
# 96   3158                    라스트 에너미  2014-03-06    23820000    23820000
# 97   3159                 넥스트 투모로우 2  2014-11-27     1626000     1626000
# 98   3160                      콜 미 킹  2016-08-18        5000        5000
# 99   3161                         로봇  2012-04-19    26607000    26607000
#
#         관객수    누적관객수  스크린수   상영횟수   대표국적                       배급사        등급  \
# 0       437      437     3     17     한국                         0      등급없음
# 1        60       60     1      1     미국          (주)제이에이와이이엔터테인먼트  15세이상관람가
# 2        17       17     5     17   뉴질랜드                   (주)풍경소리  15세이상관람가
# 3        60       60     1      1     미국               주식회사 루믹스미디어  15세이상관람가
# 4       305      305     1      2     대만                         0      등급없음
# 5         7        7     5      7    스페인               주식회사 마운틴픽쳐스  15세이상관람가
# 6         1        1     1      1     미국                주식회사 레드아이스  15세이상관람가
# 7         1        1     1      1     미국                  (주)케이알씨지  12세이상관람가
# 8         1        1     1      1     일본               (주)영진크리에이티브   청소년관람불가
# 9       107      107     1      2     미국                         0      등급없음
# 10        1        1     1      1     미국               (주)도키엔터테인먼트  15세이상관람가
# 11       60       60     1      1     미국          (주)제이에이와이이엔터테인먼트  15세이상관람가
# 12        1        1     1      1     미국                   (주)블루브릭  12세이상관람가
# 13    38736    38736    19   1551     미국             워너브러더스 코리아(주)   청소년관람불가
# 14   475309   475309   590  20692     미국             롯데쇼핑㈜롯데엔터테인먼트  15세이상관람가
# 15   576120   576120   167  15779     미국                    CJ ENM  12세이상관람가
# 16   654386   654386   284  22145     미국       한국소니픽쳐스릴리징브에나비스타영화㈜  12세이상관람가
# 17  2292172  2292172   407  59132     미국                    CJ ENM  12세이상관람가
# 18     2263     2263    15    298     영국                    ㈜인디스토리   청소년관람불가
# 19       31       31     1      3     미국                         0      등급없음
# 20        1        1     1      1     미국                주식회사 레드아이스   청소년관람불가
# 21       15       15     1      2  룩셈부르크                         0   청소년관람불가
# 22     4918     4918    12    463     미국               소니픽쳐스릴리징코리아  15세이상관람가
# 23       19       19     1      1     미국                         0  15세이상관람가
# 24    21171    21171    48   1537     미국             이십세기폭스필름코퍼레이션  15세이상관람가
# 25    48844    48844   185   2766     미국       유니버설픽쳐스인터내셔널 코리아(유)   청소년관람불가
# 26   800006   800006   312  24611     미국           (주)시너지하우스 (시너지)  15세이상관람가
# 27   851917   851917  1151  40520     미국         롯데컬처웍스(주)롯데엔터테인먼트  12세이상관람가
# 28     6445  3659683    35    972     미국       유니버설픽쳐스인터내셔널 코리아(유)  15세이상관람가
# 29      111      111     1      3     독일                         0      등급없음
# 30       53      122     1      3     미국                         0      등급없음
# 31       17      432     1      2     미국                         0      등급없음
# 32      158      158     1      6     미국                         0      등급없음
# 33       54       54     1      1     미국                 (주)엘케이픽쳐스   청소년관람불가
# 34        1        1     1      1     일본                         0   청소년관람불가
# 35   135874   135874   312   5195     미국       유니버설픽쳐스인터내셔널 코리아(유)  12세이상관람가
# 36      218      218     1      9   이탈리아                         0      등급없음
# 37       92      218     1      3    NaN                         0      등급없음
# 38       99      306     1      4     미국                         0      등급없음
# 39       24      558     1      1     미국                         0   청소년관람불가
# 40      962     2757     1     16     미국                         0   청소년관람불가
# 41     2109    12032     1     49     미국                         0      등급없음
# 42      634    13554     1     19     미국                         0  12세이상관람가
# 43        1        1     1      1     미국               (주)알이디아이스엔터   청소년관람불가
# 44     6409     7086    30    446     미국                  (주)팝파트너스  15세이상관람가
# 45    10175    10175    71   1062     미국                 (주)영화사 진진  15세이상관람가
# 46    13885    13885    33    857     미국       유니버설픽쳐스인터내셔널 코리아(유)  12세이상관람가
# 47   472157   472157   411  21884     미국                 (주)씨제이이엔엠  12세이상관람가
# 48   507889   507889   957  28696     미국        월트디즈니컴퍼니코리아 유한책임회사  12세이상관람가
# 49      166  1085447     1      1     미국                    CJ ENM  12세이상관람가
# 50  1607555  1607555   607  40563     미국                 (주)씨제이이엔엠  12세이상관람가
# 51  3273879  3273879   940  69226     미국            월트디즈니컴퍼니코리아(주)  12세이상관람가
# 52       44  5127047     2     11     미국                    UIP코리아  15세이상관람가
# 53       70       70     1      7    캐나다                         0     전체관람가
# 54      883      883     6     52     영국             (주)앤드플러스미디어웍스   청소년관람불가
# 55     1801     1801     4     18     미국                 (주)소나무픽쳐스   청소년관람불가
# 56        1        1     1      1     일본                   (주)플라이어   청소년관람불가
# 57       42       42     4     19     미국                 (주)소나무픽쳐스   청소년관람불가
# 58        1        1     1      1    캐나다                         0   청소년관람불가
# 59        1        1     1      1     미국                 (유)조이앤시네마  15세이상관람가
# 60        1        1     1      1     일본             (주)씨맥스커뮤니케이션즈   청소년관람불가
# 61        1        1     1      1     일본                  (주)빅콘미디어   청소년관람불가
# 62        1        1     1      1     일본                         0   청소년관람불가
# 63       90       90     1      1     한국                         0      등급없음
# 64     3881     3881    12     51     미국               (주)영화사 안다미로  15세이상관람가
# 65    52197    52197   279   4134     미국       유니버설픽쳐스인터내셔널 코리아(유)  15세이상관람가
# 66   110267   110267    74   4435     미국             워너브러더스 코리아(주)     전체관람가
# 67   347791   347791   245  15359     미국              이십세기폭스코리아(주)   청소년관람불가
# 68   378950   378950    81   9005     미국       한국소니픽쳐스릴리징브에나비스타영화㈜  12세이상관람가
# 69   466475   466475   837  24194     미국        월트디즈니컴퍼니코리아 유한책임회사  15세이상관람가
# 70   537920   537920   484  19867     미국  소니픽쳐스릴리징월트디즈니스튜디오스코리아(주)  12세이상관람가
# 71  1371164  1371164   399  32416     미국                    CJ ENM     전체관람가
# 72      192  1676011     1      1     미국       유니버설픽쳐스인터내셔널 코리아(유)  15세이상관람가
# 73      100     2838     1      1     인도          예지림엔터테인먼트,미디어소프트     전체관람가
# 74        1        1     1      1     터키                 (주) 케이알씨지  15세이상관람가
# 75     4012     4012   180   1479     미국    (주)스톰픽쳐스코리아,와이드 릴리즈(주)  15세이상관람가
# 76   124836   124836   194  10868    프랑스                 (주)화앤담이엔티   청소년관람불가
# 77       37       37     5     37     태국                 케이티하이텔(주)   청소년관람불가
# 78     1546     1546    20     25     태국                   (주)퍼스트런   청소년관람불가
# 79     2502     2502    13    134     태국                  (주)영화사 빅   청소년관람불가
# 80        1        1     1      1     일본               (주)영진크리에이티브   청소년관람불가
# 81     1513     1513     7    145     미국                 (주)크래커픽쳐스     전체관람가
# 82     2595     2595    20     56     한국           브릿지웍스 엔터테인먼트(주)   청소년관람불가
# 83     1422     1422     1     12     미국                         0      등급없음
# 84        4        4     1      2     인도                         0      등급없음
# 85        2        2     1      2     미국               소니픽쳐스릴리징코리아  15세이상관람가
# 86      296      296     3      4     미국            (주)고맙습니다 사랑합니다   청소년관람불가
# 87       21       21     1      2     호주                         0      등급없음
# 88   141716   141716    15   1668     미국       한국소니픽쳐스릴리징브에나비스타영화㈜     전체관람가
# 89   306459   306459   180  15062     미국       한국소니픽쳐스릴리징브에나비스타영화㈜  12세이상관람가
# 90      188      188     1      2     인도                         0      등급없음
# 91       13       13     1      2     미국                         0      등급없음
# 92        1        1     1      1     미국              모비딕엔터테인먼트(주)  15세이상관람가
# 93        1        1     1      1     미국              모비딕엔터테인먼트(주)  15세이상관람가
# 94        1        1     1      1     미국              모비딕엔터테인먼트(주)  15세이상관람가
# 95       90       90     1      9     미국                     스크린조이  15세이상관람가
# 96     4032     4032    20     85     미국                  (주)미디어데이  15세이상관람가
# 97      381      381     4     12     미국                     스크린조이  12세이상관람가
# 98        1        1     1      1     미국                (주)시네마리퍼블릭   청소년관람불가
# 99     3617     3617    37    459     인도                프리비젼엔터테인먼트  15세이상관람가
#
#        장르                    감독  \
# 0   다큐멘터리          416연대 미디어위원회
# 1     판타지             A. 토드 스미스
# 2      액션              A.K. 스트롬
# 3      공포                BC 퍼트니
# 4    장르없음                  BITO
# 5      범죄             C. 마틴 페레라
# 6    어드벤처           C. 블레이크 에번든
# 7    어드벤처            C. 토마스 하우웰
# 8   멜로로맨스                C.나가후쿠
# 9    장르없음   D.A. 페네베이커,크리스 헤지더스
# 10     SF              D.C. 해밀턴
# 11    스릴러              D.J. 비올라
# 12     가족              D.J. 카루소
# 13    스릴러              D.J. 카루소
# 14     액션              D.J. 카루소
# 15    스릴러              D.J. 카루소
# 16     액션              D.J. 카루소
# 17     액션              D.J. 카루소
# 18  멜로로맨스               D.R. 후드
# 19   장르없음             D.W. 그리피스
# 20    스릴러                  Dpyx
# 21     공포           E. 엘리아스 메리지
# 22     공포           E. 엘리아스 메리지
# 23     액션             F. 게리 그레이
# 24    코미디             F. 게리 그레이
# 25    드라마             F. 게리 그레이
# 26    스릴러             F. 게리 그레이
# 27     액션             F. 게리 그레이
# 28     액션             F. 게리 그레이
# 29   장르없음             F.W. 무르나우
# 30   장르없음             F.W. 무르나우
# 31   장르없음             F.W. 무르나우
# 32    코미디               H.C. 포터
# 33    스릴러              H.M. 콕클리
# 34  멜로로맨스                H.카와사키
# 35     액션               J 블레이크슨
# 36   어드벤처               J. 리 톰슨
# 37   장르없음               J. 리 톰슨
# 38     모험               J. 리 톰슨
# 39    드라마               J. 리 톰슨
# 40     액션               J. 리 톰슨
# 41     액션               J. 리 톰슨
# 42     전쟁               J. 리 톰슨
# 43     공포                 J. 호튼
# 44    스릴러                J.C 챈더
# 45     범죄                J.C 챈더
# 46    드라마                J.C 챈더
# 47     SF            J.J. 에이브럼스
# 48     액션            J.J. 에이브럼스
# 49     SF            J.J. 에이브럼스
# 50     액션            J.J. 에이브럼스
# 51     액션            J.J. 에이브럼스
# 52     액션            J.J. 에이브럼스
# 53     모험               J.J. 존슨
# 54     범죄               J.S 베어드
# 55     공포               J.T. 페티
# 56    드라마               J.Y 타이요
# 57    코미디              K. 애셔 레빈
# 58     액션                  K. 킹
# 59     액션                  K. 킹
# 60    드라마               K.C 타케다
# 61     에로               K.C 타케다
# 62  멜로로맨스                 K.웨스트
# 63   장르없음                   L&Z
# 64     공포             L. A. 로페스
# 65    스릴러            M. 나이트 샤말란
# 66    판타지            M. 나이트 샤말란
# 67     SF            M. 나이트 샤말란
# 68     공포            M. 나이트 샤말란
# 69    드라마            M. 나이트 샤말란
# 70     SF            M. 나이트 샤말란
# 71     액션            M. 나이트 샤말란
# 72    스릴러            M. 나이트 샤말란
# 73    드라마               M. 마니칸단
# 74     액션            M. 차가타이 토순
# 75     액션              M.J. 버세트
# 76     액션              M.J. 버세트
# 77    드라마        M.L. 반데바노프 데바쿤
# 78    드라마        M.L. 반데바노프 데바쿤
# 79  멜로로맨스        M.L. 반데바노프 데바쿤
# 80  멜로로맨스                M.카사하라
# 81  다큐멘터리              N.C. 하이킨
# 82    코미디            NEW PISTOL
# 83  다큐멘터리                  One9
# 84  다큐멘터리  P. 케림 프리드만,샤시와티 딸룩다르
# 85     액션               P.J. 페스
# 86     공포             P.J. 페티에트
# 87   장르없음               P.J. 호건
# 88   어드벤처               P.J. 호건
# 89    코미디               P.J. 호건
# 90   장르없음                 R. 발키
# 91   장르없음           R. 브래드 야하우스
# 92     액션           R. 엘리스 프레이저
# 93     액션           R. 엘리스 프레이저
# 94     액션           R. 엘리스 프레이저
# 95     액션           R. 엘리스 프레이저
# 96     액션           R. 엘리스 프레이저
# 97     액션           R.D. 브라운슈타인
# 98     액션               R.L. 스콧
# 99     SF                S. 샹카르
#
#                                                    배우
# 0                                                   0
# 1                                 애덤 존슨,로버트 제인,케빈 소르보
# 2                              모건 브래들리,그레이엄 빈센트,캠벨 루셀
# 3                                          빌 오버스트 주니어
# 4                                                   0
# 5                           안나 알렌,나초 프레스네다,메르세데스 카스트로
# 6                                           존 W. 바우어스
# 7                                  C. 토마스 하우웰,티모시 바톰즈
# 8                                     타치바나 케이코,이치죠 리노
# 9                                                   0
# 10                          지노 안소니 페시,브리나 켈리,제이슨 스튜어트
# 11                            버지니아 가드너,윌리엄 매포더,마크 롤스톤
# 12                                챈들러 캔터베리,라다 미첼,발 킬머
# 13                              에단 호크,안젤리나 졸리,키퍼 서덜랜드
# 14    빈 디젤,사무엘 L. 잭슨,루비 로즈,니나 도브레브,토니 콜렛,디피카 파드콘,토니 자
# 15                                      샤이아 라보프,사라 로머
# 16                                   티모시 올리펀트,알렉스 페티퍼
# 17                              샤이아 라보프,미셸 모나한,도니 제프콧
# 18                             베네딕트 컴버배치,클레어 포이,숀 에반스
# 19                                                  0
# 20                                            캐서린 아네트
# 21                                존 말코비치,윌렘 대포,캐리 엘위스
# 22                                      아론 에크하트,벤 킹슬리
# 23                           사무엘 L. 잭슨,케빈 스페이시,데이빗 모스
# 24                                       존 트라볼타,우마 서먼
# 25    오셔 잭슨 주니어,코리 호킨스,제이슨 미첼,닐 브라운 주니어,알디스 호지,폴 지아마티
# 26                                     제라드 버틀러,제이미 폭스
# 27                         크리스 헴스워스,테사 톰슨,리암 니슨,엠마 톰슨
# 28  빈 디젤,드웨인 존슨,샤를리즈 테론,제이슨 스타뎀,스콧 이스트우드,커트 러셀,미셸 ...
# 29                                                  0
# 30                                                  0
# 31                                                  0
# 32                                로레타 영,조셉 거튼,에델 베리모어
# 33                                      숀 패리스,다니엘 세브리
# 34                                                  0
# 35                                클로이 모레츠,닉 로빈슨,알렉스 로
# 36                                                  0
# 37                              그레고리 펙,텔리 사바라스,오마 샤리프
# 38                              율 브린너,조지 샤키리스,셜리 앤 필드
# 39                                그레고리 펙,로버트 미첨,폴리 버겐
# 40                               안소니 퀸,제임스 메이슨,말콤 맥도웰
# 41                                그레고리 펙,안소니 퀸,데이빗 니븐
# 42                               토니 커티스,율 브린너,샘 워너메이커
# 43                                                  0
# 44  케빈 스페이시,데미 무어,사이먼 베이커,재커리 퀸토,제레미 아이언스,스탠리 투치,폴...
# 45                                   오스카 아이삭,제시카 차스테인
# 46                                           로버트 레드포드
# 47                                       조엘 코트니,엘르 패닝
# 48                      데이지 리들리,아담 드라이버,오스카 아이삭,존 보예가
# 49                                 크리스 파인,재커리 퀸토,칼 어번
# 50           크리스 파인,칼 어번,조 샐다나,안톤 옐친,재커리 퀸토,베네딕트 컴버배치
# 51  해리슨 포드,마크 해밀,캐리 피셔,사이먼 페그,오스카 아이삭,막스 본 시도우,도널 글리슨
# 52                                  톰 크루즈,필립 세이모어 호프만
# 53                                      미켈라 루치,사라 초드리
# 54                              제임스 맥어보이,이모겐 푸츠,제이미 벨
# 55                                클립튼 콜린스 주니어,클랜시 브라운
# 56                                           사와무라 레이코
# 57                               카일 갈너,사라 힐랜드,제임스 벨루시
# 58                             마틴 코핑,대니 트레조,클레어 니더프루엠
# 59                               이브 마우로,로키 마이어스,애덤 존슨
# 60                                           카와카미 나나미
# 61                                                  0
# 62                                                  0
# 63                                                  0
# 64                             린제이 세임,데니스 안드레스,안소니 불리
# 65                     디애너 듀나건,피터 맥로비,에드 옥슨볼드,올리비아 데종
# 66                                폴 지아마티,브라이스 달라스 하워드
# 67                        마크 웰버그,주이 데샤넬,존 레귀자모,마크 월버그
# 68                                와킨 피닉스,브라이스 달라스 하워드
# 69         제임스 맥어보이,브루스 윌리스,사무엘 L. 잭슨,안야 테일러 조이,사라 폴슨
# 70                                      윌 스미스,제이든 스미스
# 71                          잭슨 라스본,데브 파텔,노아 링어,니콜라 펠츠
# 72  제임스 맥어보이,안야 테일러 조이,헤일리 루 리차드슨,베티 버클리,브래드 윌리엄 헨...
# 73                                         아이시와리아 라제시
# 74                                              케렘 버신
# 75                                      메간 폭스,필립 윈체스터
# 76                        제임스 퓨어포이,레이첼 허드-우드,막스 본 시도우
# 77                                   카르피찰 케트마니,사크릿 얌냠
# 78                               마리오 마우러,야야잉,봉코이 콩말라이
# 79                         마리오 마우러,야야잉,봉코이 콩말라이,니시노 쇼
# 80                                           이케타니 사나에
# 81                                        강철환,김철웅,변옥선
# 82                        사토미 유리아,윤설희,안진우,조정윤,김광현,곽한구
# 83                                                  0
# 84                                                  0
# 85                                        톰 베린저,바이런 만
# 86                                     발레리 아즐린,케빈 소르보
# 87                                                  0
# 88                          레이첼 허드-우드,제이슨 아이삭스,제레미 섬터
# 89                                  아일라 피셔,휴 댄시,조앤 쿠삭
# 90                                                  0
# 91                                                  0
# 92                                            게리 다니엘스
# 93                                            돌프 룬드그렌
# 94                                            게리 다니엘스
# 95                            에이단 퀸,앤디 가르시아,마리오 반 피블스
# 96                                        루크 고스,콜 하우저
# 97                                             제프 파헤이
# 98                    아민 조셉,크리스 멀키,링 바이,빌 콥스,가브리엘 데니스
# 99                             라지니 칸트,아이쉬와라 라이,대니 덴종파

# %% [markdown]
# ### 중간 저장

# %%
df.to_csv("중간저장.csv" ,encoding = 'utf-8-sig')

# %%
movie = pd.read_csv("중간저장.csv", index_col = False, thousands = ',')
movie = movie.loc[:, "영화명" : "배우"]
movie
# Out:
#                                영화명         개봉일      매출액    누적매출액  관객수  누적관객수  \
# 0          416 프로젝트 "공동의 기억: 트라우마"         NaN  2192500  2192500  437    437
# 1                     미씨카: 더 네크로맨서  2017-11-02   300000   300000   60     60
# 2                     월드 워 핵전쟁의 서막  2019-03-07    26000    26000   17     17
# 3                            울프라이징  2016-11-17   300000   300000   60     60
# 4                  제3의앵글 : 형형색색대만전         NaN  1830000  1830000  305    305
# ...                            ...         ...      ...      ...  ...    ...
# 21320                      댄싱 인 자파         NaN    88000    88000   15     15
# 21321                  위기의 30대 여자들         NaN   946400   946400  136    136
# 21322                   16세의 사운드트랙  2020-07-02  3543400  3543400  413    413
# 21323  나의 말을 지켜봐: 어느 귀 먼 연예인들의 이야기         NaN   293500   293500  114    114
# 21324                       분노의 건샷  2016-12-14     4000     4000    1      1
#
#        스크린수  상영횟수  대표국적               배급사        등급     장르            감독  \
# 0         3    17    한국                 0      등급없음  다큐멘터리  416연대 미디어위원회
# 1         1     1    미국  (주)제이에이와이이엔터테인먼트  15세이상관람가    판타지     A. 토드 스미스
# 2         5    17  뉴질랜드           (주)풍경소리  15세이상관람가     액션      A.K. 스트롬
# 3         1     1    미국       주식회사 루믹스미디어  15세이상관람가     공포        BC 퍼트니
# 4         1     2    대만                 0      등급없음   장르없음          BITO
# ...     ...   ...   ...               ...       ...    ...           ...
# 21320     1     2    미국                 0      등급없음  다큐멘터리       힐라 메달리아
# 21321     1     2  이스라엘                 0      등급없음  다큐멘터리       힐라 메달리아
# 21322    19   150    영국       (주)마노엔터테인먼트  12세이상관람가    코미디     힐러리 셰익스피어
# 21323     1     2    미국                 0      등급없음  다큐멘터리        힐러리 스칼
# 21324     1     1    미국         (주) 케이알씨지  15세이상관람가     범죄      힐러리안 뱅크스
#
#                                  배우
# 0                                 0
# 1               애덤 존슨,로버트 제인,케빈 소르보
# 2            모건 브래들리,그레이엄 빈센트,캠벨 루셀
# 3                        빌 오버스트 주니어
# 4                                 0
# ...                             ...
# 21320                             0
# 21321                             0
# 21322               제임스 캘로웨이,스칼렛 마셜
# 21323                             0
# 21324  제임스 와일더,조아큄 드 알메이다,레베카 메이 파머
#
# [21325 rows x 14 columns]

# %% [markdown]
# ### 8. 배급사

# %%
# 배급사 1명만 남기기

# for i in range(len(df["배급사"])):
#     if type(df["배급사"][i]) == float:
#         df["배급사"][i] = 0
#     else:
#         df["배급사"][i] = df["배급사"][i].split(",")[0]
